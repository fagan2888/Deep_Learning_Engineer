# %% [markdown]
# ## 卷积神经网络（Convolutional Neural Network, CNN）
#
# ## 项目：实现一个狗品种识别算法App
#
# 在这个notebook文件中，有些模板代码已经提供给你，但你还需要实现更多的功能来完成这个项目。除非有明确要求，你无须修改任何已给出的代码。以**'(练习)'**开始的标题表示接下来的代码部分中有你需要实现的功能。这些部分都配有详细的指导，需要实现的部分也会在注释中以'TODO'标出。请仔细阅读所有的提示。
#
# 除了实现代码外，你还**需要**回答一些与项目及代码相关的问题。每个需要回答的问题都会以 **'问题 X'** 标记。请仔细阅读每个问题，并且在问题后的 **'回答'** 部分写出完整的答案。我们将根据 你对问题的回答 和 撰写代码实现的功能 来对你提交的项目进行评分。
#
# >**提示：**Code 和 Markdown 区域可通过 **Shift + Enter** 快捷键运行。此外，Markdown可以通过双击进入编辑模式。
#
# 项目中显示为_选做_的部分可以帮助你的项目脱颖而出，而不是仅仅达到通过的最低要求。如果你决定追求更高的挑战，请在此 notebook 中完成_选做_部分的代码。
#
# ---
#
# ### 让我们开始吧
# 在这个notebook中，你将迈出第一步，来开发可以作为移动端或 Web应用程序一部分的算法。在这个项目的最后，你的程序将能够把用户提供的任何一个图像作为输入。如果可以从图像中检测到一只狗，它会输出对狗品种的预测。如果图像中是一个人脸，它会预测一个与其最相似的狗的种类。下面这张图展示了完成项目后可能的输出结果。（……实际上我们希望每个学生的输出结果不相同！）
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# 在现实世界中，你需要拼凑一系列的模型来完成不同的任务；举个例子，用来预测狗种类的算法会与预测人类的算法不同。在做项目的过程中，你可能会遇到不少失败的预测，因为并不存在完美的算法和模型。你最终提交的不完美的解决方案也一定会给你带来一个有趣的学习经验！
#
# ### 项目内容
#
# 我们将这个notebook分为不同的步骤，你可以使用下面的链接来浏览此notebook。
#
# * [Step 0](#step0): 导入数据集
# * [Step 1](#step1): 检测人脸
# * [Step 2](#step2): 检测狗狗
# * [Step 3](#step3): 从头创建一个CNN来分类狗品种
# * [Step 4](#step4): 使用一个CNN来区分狗的品种(使用迁移学习)
# * [Step 5](#step5): 建立一个CNN来分类狗的品种（使用迁移学习）
# * [Step 6](#step6): 完成你的算法
# * [Step 7](#step7): 测试你的算法
#
# 在该项目中包含了如下的问题：
#
# * [问题 1](#question1)
# * [问题 2](#question2)
# * [问题 3](#question3)
# * [问题 4](#question4)
# * [问题 5](#question5)
# * [问题 6](#question6)
# * [问题 7](#question7)
# * [问题 8](#question8)
# * [问题 9](#question9)
# * [问题 10](#question10)
# * [问题 11](#question11)
#
#
# ---
# <a id='step0'></a>
# ## 步骤 0: 导入数据集
#
# ### 导入狗数据集
# 在下方的代码单元（cell）中，我们导入了一个狗图像的数据集。我们使用 scikit-learn 库中的 `load_files` 函数来获取一些变量：
# - `train_files`, `valid_files`, `test_files` - 包含图像的文件路径的numpy数组
# - `train_targets`, `valid_targets`, `test_targets` - 包含独热编码分类标签的numpy数组
# - `dog_names` - 由字符串构成的与标签相对应的狗的种类

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('/data/dog_images/train')
valid_files, valid_targets = load_dataset('/data/dog_images/valid')
test_files, test_targets = load_dataset('/data/dog_images/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("/data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# print(test_files)
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### 导入人脸数据集
#
# 在下方的代码单元中，我们导入人脸图像数据集，文件所在路径存储在名为 `human_files` 的 numpy 数组。

# %%
import random
random.seed(8675309)

# 加载打乱后的人脸数据集的文件名
human_files = np.array(glob("/data/lfw/*/*"))
random.shuffle(human_files)

# 打印数据集的数据量
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## 步骤1：检测人脸
#
# 我们将使用 OpenCV 中的 [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) 来检测图像中的人脸。OpenCV 提供了很多预训练的人脸检测模型，它们以XML文件保存在 [github](https://github.com/opencv/opencv/tree/master/data/haarcascades)。我们已经下载了其中一个检测模型，并且把它存储在 `haarcascades` 的目录中。
#
# 在如下代码单元中，我们将演示如何使用这个检测模型在样本图像中找到人脸。

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# 提取预训练的人脸检测模型
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# 加载彩色（通道顺序为BGR）图像
img = cv2.imread(human_files[3])

# 将BGR图像进行灰度处理
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 在图像中找出脸
faces = face_cascade.detectMultiScale(gray)

# 打印图像中检测到的脸的个数
print('Number of faces detected:', len(faces))

# 获取每一个所检测到的脸的识别框
for (x,y,w,h) in faces:
    # 在人脸图像中绘制出识别框
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# 将BGR图像转变为RGB图像以打印
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 展示含有识别框的图像
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# 在使用任何一个检测模型之前，将图像转换为灰度图是常用过程。`detectMultiScale` 函数使用储存在 `face_cascade` 中的的数据，对输入的灰度图像进行分类。
#
# 在上方的代码中，`faces` 以 numpy 数组的形式，保存了识别到的面部信息。它其中每一行表示一个被检测到的脸，该数据包括如下四个信息：前两个元素  `x`、`y` 代表识别框左上角的 x 和 y 坐标（参照上图，注意 y 坐标的方向和我们默认的方向不同）；后两个元素代表识别框在 x 和 y 轴两个方向延伸的长度 `w` 和 `d`。
#
# ### 写一个人脸识别器
#
# 我们可以将这个程序封装为一个函数。该函数的输入为人脸图像的**路径**，当图像中包含人脸时，该函数返回 `True`，反之返回 `False`。该函数定义如下所示。

# %%
# 如果img_path路径表示的图像检测到了脸，返回"True" 
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### **【练习】** 评估人脸检测模型

# %% [markdown]
# ---
#
# <a id='question1'></a>
# ### __问题 1:__
#
# 在下方的代码块中，使用 `face_detector` 函数，计算：
#
# - `human_files` 的前100张图像中，能够检测到**人脸**的图像占比多少？
# - `dog_files` 的前100张图像中，能够检测到**人脸**的图像占比多少？
#
# 理想情况下，人图像中检测到人脸的概率应当为100%，而狗图像中检测到人脸的概率应该为0%。你会发现我们的算法并非完美，但结果仍然是可以接受的。我们从每个数据集中提取前100个图像的文件路径，并将它们存储在`human_files_short`和`dog_files_short`中。

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
## 请不要修改上方代码


## TODO: 基于human_files_short和dog_files_short
## 中的图像测试face_detector的表现
CntHuman_Human=0
CntDog_Human=0
for i in range(100):
    if(face_detector(human_files_short[i])==True):
        CntHuman_Human+=1
    if(face_detector(dog_files_short[i])==True):
        CntDog_Human+=1

# %%
print(CntHuman_Human)
print(CntDog_Human)
# Out:
# 100
# 11

# %% [markdown]
# ---
#
# <a id='question2'></a>
#
# ### __问题 2:__
#
# 就算法而言，该算法成功与否的关键在于，用户能否提供含有清晰面部特征的人脸图像。
# 那么你认为，这样的要求在实际使用中对用户合理吗？如果你觉得不合理，你能否想到一个方法，即使图像中并没有清晰的面部特征，也能够检测到人脸？
#
# __回答:__
# 这明显是一个不合理的期望，因为我们的模型是使用全正面人脸来创建的，用于检测全正面人脸，所以它在检测半面人脸方面可能不太好。半脸和侧脸是常见的情况。因此我们可以使用谷歌的OpenFACE来处理半脸和侧脸的情况。

# %% [markdown]
# ---
#
# <a id='Selection1'></a>
# ### 选做：
#
# 我们建议在你的算法中使用opencv的人脸检测模型去检测人类图像，不过你可以自由地探索其他的方法，尤其是尝试使用深度学习来解决它:)。请用下方的代码单元来设计和测试你的面部监测算法。如果你决定完成这个_选做_任务，你需要报告算法在每一个数据集上的表现。

# %%
## (选做) TODO: 报告另一个面部检测算法在LFW数据集上的表现
### 你可以随意使用所需的代码单元数
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint

def load_resized(img_path):
    print("Img: {}".format(img_path))
    img = cv2.imread(img_path)
    return cv2.resize(img, (224, 224))

humans_X = [load_resized(i) for i in human_files]
dogs_X = [load_resized(i) for i in train_files]
# Out:
# Img: /data/lfw/Rick_Dinse/Rick_Dinse_0002.jpg
# Img: /data/lfw/JC_Chasez/JC_Chasez_0001.jpg
# Img: /data/lfw/Carlos_Menem/Carlos_Menem_0013.jpg
# Img: /data/lfw/Khatol_Mohammad_Zai/Khatol_Mohammad_Zai_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0060.jpg
# Img: /data/lfw/Ray_Nagin/Ray_Nagin_0002.jpg
# Img: /data/lfw/Joschka_Fischer/Joschka_Fischer_0018.jpg
# Img: /data/lfw/Steven_Spielberg/Steven_Spielberg_0001.jpg
# Img: /data/lfw/Fernando_Leon_de_Aranoa/Fernando_Leon_de_Aranoa_0001.jpg
# Img: /data/lfw/James_Wolfensohn/James_Wolfensohn_0002.jpg
# Img: /data/lfw/Roberta_Combs/Roberta_Combs_0001.jpg
# Img: /data/lfw/Mariah_Carey/Mariah_Carey_0001.jpg
# Img: /data/lfw/Nancy_Pelosi/Nancy_Pelosi_0008.jpg
# Img: /data/lfw/Mahmoud_Abbas/Mahmoud_Abbas_0001.jpg
# Img: /data/lfw/Roh_Moo-hyun/Roh_Moo-hyun_0017.jpg
# Img: /data/lfw/Bill_Herrion/Bill_Herrion_0001.jpg
# Img: /data/lfw/Meryl_Streep/Meryl_Streep_0002.jpg
# Img: /data/lfw/Guillermo_Canas/Guillermo_Canas_0002.jpg
# Img: /data/lfw/Kajsa_Bergqvist/Kajsa_Bergqvist_0001.jpg
# Img: /data/lfw/Natalie_Coughlin/Natalie_Coughlin_0006.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0050.jpg
# Img: /data/lfw/Juan_Manuel_Marquez/Juan_Manuel_Marquez_0002.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0223.jpg
# Img: /data/lfw/Leticia_Dolera/Leticia_Dolera_0001.jpg
# Img: /data/lfw/Cho_Myung-kyun/Cho_Myung-kyun_0001.jpg
# Img: /data/lfw/Roger_Staubach/Roger_Staubach_0001.jpg
# Img: /data/lfw/John_Lithgow/John_Lithgow_0001.jpg
# Img: /data/lfw/Richard_Shelby/Richard_Shelby_0002.jpg
# Img: /data/lfw/Hans_Blix/Hans_Blix_0013.jpg
# Img: /data/lfw/Alain_Ducasse/Alain_Ducasse_0001.jpg
# Img: /data/lfw/Glenn_Tilton/Glenn_Tilton_0001.jpg
# Img: /data/lfw/Della_Clara/Della_Clara_0001.jpg
# Img: /data/lfw/Mike_Weir/Mike_Weir_0001.jpg
# Img: /data/lfw/Natalie_Imbruglia/Natalie_Imbruglia_0001.jpg
# Img: /data/lfw/Faye_Dunaway/Faye_Dunaway_0003.jpg
# Img: /data/lfw/Marsha_Thomason/Marsha_Thomason_0001.jpg
# Img: /data/lfw/Donald_Rumsfeld/Donald_Rumsfeld_0118.jpg
# Img: /data/lfw/Khalid_Qazi/Khalid_Qazi_0001.jpg
# Img: /data/lfw/Silvan_Shalom/Silvan_Shalom_0001.jpg
# Img: /data/lfw/Randall_Tobias/Randall_Tobias_0001.jpg
# Img: /data/lfw/Fernando_Gonzalez/Fernando_Gonzalez_0004.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0097.jpg
# Img: /data/lfw/Donald_Rumsfeld/Donald_Rumsfeld_0047.jpg
# Img: /data/lfw/Vladimir_Putin/Vladimir_Putin_0020.jpg
# Img: /data/lfw/Todd_Wike/Todd_Wike_0001.jpg
# Img: /data/lfw/Adrien_Brody/Adrien_Brody_0012.jpg
# Img: /data/lfw/Marcelo_Rios/Marcelo_Rios_0002.jpg
# Img: /data/lfw/Stefan_Tafrov/Stefan_Tafrov_0001.jpg
# Img: /data/lfw/Zakia_Hakki/Zakia_Hakki_0001.jpg
# Img: /data/lfw/Laura_Bozzo/Laura_Bozzo_0001.jpg
# Img: /data/lfw/John_Kerry/John_Kerry_0012.jpg
# Img: /data/lfw/Winona_Ryder/Winona_Ryder_0012.jpg
# Img: /data/lfw/Jean-Pierre_Bemba/Jean-Pierre_Bemba_0001.jpg
# Img: /data/lfw/Nathalie_Baye/Nathalie_Baye_0004.jpg
# Img: /data/lfw/Claudia_Coslovich/Claudia_Coslovich_0001.jpg
# Img: /data/lfw/Serena_Williams/Serena_Williams_0033.jpg
# Img: /data/lfw/Michelle_Pfeiffer/Michelle_Pfeiffer_0003.jpg
# Img: /data/lfw/Darrell_Issa/Darrell_Issa_0002.jpg
# Img: /data/lfw/Ariel_Sharon/Ariel_Sharon_0007.jpg
# Img: /data/lfw/Brad_Johnson/Brad_Johnson_0001.jpg
# Img: /data/lfw/Glafcos_Clerides/Glafcos_Clerides_0001.jpg
# Img: /data/lfw/Edward_Belvin/Edward_Belvin_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0049.jpg
# Img: /data/lfw/Jaymon_Crabb/Jaymon_Crabb_0001.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0062.jpg
# Img: /data/lfw/Raag_Singhal/Raag_Singhal_0001.jpg
# Img: /data/lfw/Bashar_Assad/Bashar_Assad_0003.jpg
# Img: /data/lfw/Alec_Baldwin/Alec_Baldwin_0003.jpg
# Img: /data/lfw/Richard_Haass/Richard_Haass_0002.jpg
# Img: /data/lfw/Luiz_Felipe_Scolari/Luiz_Felipe_Scolari_0002.jpg
# Img: /data/lfw/Alan_Greer/Alan_Greer_0001.jpg
# Img: /data/lfw/Bill_Paxton/Bill_Paxton_0001.jpg
# Img: /data/lfw/Scott_Peterson/Scott_Peterson_0004.jpg
# Img: /data/lfw/Fernando_Henrique_Cardoso/Fernando_Henrique_Cardoso_0003.jpg
# Img: /data/lfw/Bill_Gates/Bill_Gates_0004.jpg
# Img: /data/lfw/Vincent_Brooks/Vincent_Brooks_0006.jpg
# Img: /data/lfw/Ronaldo_Luis_Nazario_de_Lima/Ronaldo_Luis_Nazario_de_Lima_0001.jpg
# Img: /data/lfw/Edwin_Edwards/Edwin_Edwards_0001.jpg
# Img: /data/lfw/Kamel_Morjane/Kamel_Morjane_0001.jpg
# Img: /data/lfw/Jose_Maria_Aznar/Jose_Maria_Aznar_0019.jpg
# Img: /data/lfw/Cheryl_Tiegs/Cheryl_Tiegs_0001.jpg
# Img: /data/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0008.jpg
# Img: /data/lfw/Martin_Howard/Martin_Howard_0001.jpg
# Img: /data/lfw/Padraig_Harrington/Padraig_Harrington_0002.jpg
# Img: /data/lfw/Nastassia_Kinski/Nastassia_Kinski_0001.jpg
# Img: /data/lfw/Ricardo_Lagos/Ricardo_Lagos_0011.jpg
# Img: /data/lfw/Tim_Henman/Tim_Henman_0019.jpg
# Img: /data/lfw/Aretha_Franklin/Aretha_Franklin_0001.jpg
# Img: /data/lfw/Mahmoud_Abbas/Mahmoud_Abbas_0027.jpg
# Img: /data/lfw/Lindsay_Davenport/Lindsay_Davenport_0018.jpg
# Img: /data/lfw/Kate_Richardson/Kate_Richardson_0001.jpg
# Img: /data/lfw/David_Ho/David_Ho_0001.jpg
# Img: /data/lfw/Steven_Hatfill/Steven_Hatfill_0001.jpg
# Img: /data/lfw/Dalai_Lama/Dalai_Lama_0002.jpg
# Img: /data/lfw/John_Kerry/John_Kerry_0015.jpg
# Img: /data/lfw/Charles_Pouty/Charles_Pouty_0001.jpg
# Img: /data/lfw/Paul_Sarbanes/Paul_Sarbanes_0003.jpg
# Img: /data/lfw/Romano_Prodi/Romano_Prodi_0006.jpg
# Img: /data/lfw/Franz_Muentefering/Franz_Muentefering_0004.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0348.jpg
# Img: /data/lfw/Sarah_Jessica_Parker/Sarah_Jessica_Parker_0004.jpg
# Img: /data/lfw/Eva_Herzigova/Eva_Herzigova_0001.jpg
# Img: /data/lfw/Kaisser_Bazan/Kaisser_Bazan_0001.jpg
# Img: /data/lfw/Stephanie_Moore/Stephanie_Moore_0001.jpg
# Img: /data/lfw/Hugo_Chavez/Hugo_Chavez_0055.jpg
# Img: /data/lfw/Mary_Elizabeth_Mastrantonio/Mary_Elizabeth_Mastrantonio_0001.jpg
# Img: /data/lfw/Walter_Mondale/Walter_Mondale_0006.jpg
# Img: /data/lfw/John_Paul_II/John_Paul_II_0001.jpg
# Img: /data/lfw/Ian_Wilmut/Ian_Wilmut_0001.jpg
# Img: /data/lfw/Stephen_Keener/Stephen_Keener_0001.jpg
# Img: /data/lfw/Emilio_Botin/Emilio_Botin_0001.jpg
# Img: /data/lfw/Wang_Fei/Wang_Fei_0001.jpg
# Img: /data/lfw/John_Ashcroft/John_Ashcroft_0006.jpg
# Img: /data/lfw/Gwyneth_Paltrow/Gwyneth_Paltrow_0005.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0052.jpg
# Img: /data/lfw/Thomas_OBrien/Thomas_OBrien_0002.jpg
# Img: /data/lfw/Mario_Dumont/Mario_Dumont_0001.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0101.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0104.jpg
# Img: /data/lfw/Jennifer_Capriati/Jennifer_Capriati_0009.jpg
# Img: /data/lfw/Peter_Harvey/Peter_Harvey_0001.jpg
# Img: /data/lfw/Elisabeth_Schumacher/Elisabeth_Schumacher_0001.jpg
# Img: /data/lfw/Joseph_Ganim/Joseph_Ganim_0001.jpg
# Img: /data/lfw/Lynne_Cheney/Lynne_Cheney_0003.jpg
# Img: /data/lfw/Yao_Ming/Yao_Ming_0003.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0469.jpg
# Img: /data/lfw/Hamid_Karzai/Hamid_Karzai_0014.jpg
# Img: /data/lfw/Sheila_Copps/Sheila_Copps_0001.jpg
# Img: /data/lfw/John_Walsh/John_Walsh_0001.jpg
# Img: /data/lfw/Larry_Beinfest/Larry_Beinfest_0001.jpg
# Img: /data/lfw/Carl_Reiner/Carl_Reiner_0002.jpg
# Img: /data/lfw/Raul_Gonzalez/Raul_Gonzalez_0001.jpg
# Img: /data/lfw/Roman_Polanski/Roman_Polanski_0001.jpg
# Img: /data/lfw/Rohinton_Mistry/Rohinton_Mistry_0001.jpg
# Img: /data/lfw/Eloy_Gutierrez/Eloy_Gutierrez_0001.jpg
# Img: /data/lfw/Oscar_Bolanos/Oscar_Bolanos_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0491.jpg
# Img: /data/lfw/Vince_Carter/Vince_Carter_0002.jpg
# Img: /data/lfw/Guillermo_Coria/Guillermo_Coria_0020.jpg
# Img: /data/lfw/Jennifer_McCoy/Jennifer_McCoy_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0235.jpg
# Img: /data/lfw/Joschka_Fischer/Joschka_Fischer_0002.jpg
# Img: /data/lfw/Barry_Diller/Barry_Diller_0001.jpg
# Img: /data/lfw/Larry_Johnson/Larry_Johnson_0002.jpg
# Img: /data/lfw/Jiang_Zemin/Jiang_Zemin_0013.jpg
# Img: /data/lfw/Megawati_Sukarnoputri/Megawati_Sukarnoputri_0026.jpg
# Img: /data/lfw/Daniel_Day-Lewis/Daniel_Day-Lewis_0002.jpg
# Img: /data/lfw/Dennis_Kucinich/Dennis_Kucinich_0006.jpg
# Img: /data/lfw/Joe_Torre/Joe_Torre_0001.jpg
# Img: /data/lfw/Phil_Bredesen/Phil_Bredesen_0001.jpg
# Img: /data/lfw/Jim_Letten/Jim_Letten_0001.jpg
# Img: /data/lfw/Mary-Kate_Olsen/Mary-Kate_Olsen_0001.jpg
# Img: /data/lfw/Celine_Dion/Celine_Dion_0008.jpg
# Img: /data/lfw/Salma_Hayek/Salma_Hayek_0008.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0054.jpg
# Img: /data/lfw/Sila_Calderon/Sila_Calderon_0004.jpg
# Img: /data/lfw/Humberto_Coelho/Humberto_Coelho_0001.jpg
# Img: /data/lfw/Nick_Price/Nick_Price_0001.jpg
# Img: /data/lfw/Dave_McGinnis/Dave_McGinnis_0001.jpg
# Img: /data/lfw/Jeffrey_Immelt/Jeffrey_Immelt_0001.jpg
# Img: /data/lfw/Kofi_Annan/Kofi_Annan_0017.jpg
# Img: /data/lfw/Wan_Yanhai/Wan_Yanhai_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0365.jpg
# Img: /data/lfw/Ed_Rosenthal/Ed_Rosenthal_0001.jpg
# Img: /data/lfw/Augustin_Calleri/Augustin_Calleri_0001.jpg
# Img: /data/lfw/Rita_Moreno/Rita_Moreno_0002.jpg
# Img: /data/lfw/Rosemarie_Stack/Rosemarie_Stack_0002.jpg
# Img: /data/lfw/Jim_Haslett/Jim_Haslett_0001.jpg
# Img: /data/lfw/John_Burkett/John_Burkett_0001.jpg
# Img: /data/lfw/Ward_Cuff/Ward_Cuff_0001.jpg
# Img: /data/lfw/George_P_Bush/George_P_Bush_0002.jpg
# Img: /data/lfw/Benjamin_Netanyahu/Benjamin_Netanyahu_0003.jpg
# Img: /data/lfw/James_Phelps/James_Phelps_0001.jpg
# Img: /data/lfw/Stanley_McChrystal/Stanley_McChrystal_0001.jpg
# Img: /data/lfw/Matt_Doherty/Matt_Doherty_0003.jpg
# Img: /data/lfw/Richard_Gephardt/Richard_Gephardt_0001.jpg
# Img: /data/lfw/John_Barnett/John_Barnett_0001.jpg
# Img: /data/lfw/Derek_Jeter/Derek_Jeter_0003.jpg
# Img: /data/lfw/German_Khan/German_Khan_0001.jpg
# Img: /data/lfw/Jacques_Chirac/Jacques_Chirac_0006.jpg
# Img: /data/lfw/Christopher_Reeve/Christopher_Reeve_0002.jpg
# Img: /data/lfw/Allyson_Felix/Allyson_Felix_0002.jpg
# Img: /data/lfw/Brenda_van_Dam/Brenda_van_Dam_0001.jpg
# Img: /data/lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg
# Img: /data/lfw/Jeb_Bush/Jeb_Bush_0005.jpg
# Img: /data/lfw/Lisa_Stone/Lisa_Stone_0001.jpg
# Img: /data/lfw/Pierce_Brosnan/Pierce_Brosnan_0002.jpg
# Img: /data/lfw/Nikki_McKibbin/Nikki_McKibbin_0001.jpg
# Img: /data/lfw/Laura_Bush/Laura_Bush_0012.jpg
# Img: /data/lfw/Carey_Lowell/Carey_Lowell_0001.jpg
# Img: /data/lfw/Tony_Stewart/Tony_Stewart_0003.jpg
# Img: /data/lfw/Jennifer_Aniston/Jennifer_Aniston_0015.jpg
# Img: /data/lfw/Zinedine_Zidane/Zinedine_Zidane_0004.jpg
# Img: /data/lfw/Julio_Rossi/Julio_Rossi_0001.jpg
# Img: /data/lfw/Hans_Blix/Hans_Blix_0038.jpg
# Img: /data/lfw/Princess_Masako/Princess_Masako_0002.jpg
# Img: /data/lfw/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0014.jpg
# Img: /data/lfw/Mitchell_Crooks/Mitchell_Crooks_0001.jpg
# Img: /data/lfw/George_Bovell/George_Bovell_0001.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0166.jpg
# Img: /data/lfw/Mahima_Chaudhari/Mahima_Chaudhari_0001.jpg
# Img: /data/lfw/William_Macy/William_Macy_0005.jpg
# Img: /data/lfw/Petro_Symonenko/Petro_Symonenko_0002.jpg
# Img: /data/lfw/Razali_Ismail/Razali_Ismail_0001.jpg
# Img: /data/lfw/Silvio_Berlusconi/Silvio_Berlusconi_0006.jpg
# Img: /data/lfw/Lleyton_Hewitt/Lleyton_Hewitt_0010.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_
# Img: /data/lfw/Diane_Lane/Diane_Lane_0001.jpg
# Img: /data/lfw/Rainer_Gut/Rainer_Gut_0001.jpg
# Img: /data/lfw/Jim_Tressel/Jim_Tressel_0001.jpg
# Img: /data/lfw/Beatrice_Dalle/Beatrice_Dalle_0001.jpg
# Img: /data/lfw/Keanu_Reeves/Keanu_Reeves_0001.jpg
# Img: /data/lfw/Megawati_Sukarnoputri/Megawati_Sukarnoputri_0011.jpg
# Img: /data/lfw/Bill_Gates/Bill_Gates_0010.jpg
# Img: /data/lfw/Tim_Conway/Tim_Conway_0003.jpg
# Img: /data/lfw/Hillary_Clinton/Hillary_Clinton_0004.jpg
# Img: /data/lfw/Octavio_Lara/Octavio_Lara_0001.jpg
# Img: /data/lfw/Alex_Gonzalez/Alex_Gonzalez_0001.jpg
# Img: /data/lfw/Shania_Twain/Shania_Twain_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0247.jpg
# Img: /data/lfw/Rudolph_Giuliani/Rudolph_Giuliani_0023.jpg
# Img: /data/lfw/Felipe_Fernandez/Felipe_Fernandez_0001.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0005.jpg
# Img: /data/lfw/Rolf_Zimmermann/Rolf_Zimmermann_0001.jpg
# Img: /data/lfw/Tom_Daschle/Tom_Daschle_0016.jpg
# Img: /data/lfw/Michael_Stark/Michael_Stark_0001.jpg
# Img: /data/lfw/Lubomir_Zaoralek/Lubomir_Zaoralek_0001.jpg
# Img: /data/lfw/John_Ashcroft/John_Ashcroft_0016.jpg
# Img: /data/lfw/Hans_Blix/Hans_Blix_0006.jpg
# Img: /data/lfw/Oprah_Winfrey/Oprah_Winfrey_0001.jpg
# Img: /data/lfw/Hans_Blix/Hans_Blix_0005.jpg
# Img: /data/lfw/Mahmoud_Abbas/Mahmoud_Abbas_0015.jpg
# Img: /data/lfw/John_Kerry/John_Kerry_0003.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0029.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0443.jpg
# Img: /data/lfw/Derek_Jeter/Derek_Jeter_0004.jpg
# Img: /data/lfw/Mick_McCarthy/Mick_McCarthy_0001.jpg
# Img: /data/lfw/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0003.jpg
# Img: /data/lfw/Ralf_Schumacher/Ralf_Schumacher_0004.jpg
# Img: /data/lfw/Kofi_Annan/Kofi_Annan_0012.jpg
# Img: /data/lfw/Jason_Alexander/Jason_Alexander_0002.jpg
# Img: /data/lfw/James_Murdoch/James_Murdoch_0001.jpg
# Img: /data/lfw/Dustin_Brown/Dustin_Brown_0001.jpg
# Img: /data/lfw/John_McCain/John_McCain_0007.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0134.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0311.jpg
# Img: /data/lfw/Cheryl_Hines/Cheryl_Hines_0001.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0030.jpg
# Img: /data/lfw/Elizabeth_Hurley/Elizabeth_Hurley_0005.jpg
# Img: /data/lfw/Sabah_Al-Ahmad_Al-Jaber_Al-Sabah/Sabah_Al-Ahmad_Al-Jaber_Al-Sabah_0001.jpg
# Img: /data/lfw/Ray_Nagin/Ray_Nagin_0001.jpg
# Img: /data/lfw/Hector_Babenco/Hector_Babenco_0003.jpg
# Img: /data/lfw/David_Beckham/David_Beckham_0030.jpg
# Img: /data/lfw/David_Heyman/David_Heyman_0001.jpg
# Img: /data/lfw/Ibrahim_Rugova/Ibrahim_Rugova_0001.jpg
# Img: /data/lfw/King_Abdullah_II/King_Abdullah_II_0003.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0181.jpg
# Img: /data/lfw/Samantha_Daniels/Samantha_Daniels_0001.jpg
# Img: /data/lfw/James_Traficant/James_Traficant_0002.jpg
# Img: /data/lfw/John_Connolly/John_Connolly_0001.jpg
# Img: /data/lfw/Robert_Ehrlich/Robert_Ehrlich_0002.jpg
# Img: /data/lfw/Elton_John/Elton_John_0004.jpg
# Img: /data/lfw/Muffet_McGraw/Muffet_McGraw_0001.jpg
# Img: /data/lfw/Anna_Kournikova/Anna_Kournikova_0005.jpg
# Img: /data/lfw/Abdullah_Gul/Abdullah_Gul_0006.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0332.jpg
# Img: /data/lfw/Pat_Burns/Pat_Burns_0002.jpg
# Img: /data/lfw/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0012.jpg
# Img: /data/lfw/Vicente_Fernandez/Vicente_Fernandez_0001.jpg
# Img: /data/lfw/Bill_Sizemore/Bill_Sizemore_0001.jpg
# Img: /data/lfw/Jesse_Harris/Jesse_Harris_0003.jpg
# Img: /data/lfw/Junichiro_Koizumi/Junichiro_Koizumi_0010.jpg
# Img: /data/lfw/Robert_Hanssen/Robert_Hanssen_0001.jpg
# Img: /data/lfw/Mike_Alden/Mike_Alden_0001.jpg
# Img: /data/lfw/Suh_Chung-won/Suh_Chung-won_0001.jpg
# Img: /data/lfw/Charles_Taylor/Charles_Taylor_0006.jpg
# Img: /data/lfw/Serena_Williams/Serena_Williams_0045.jpg
# Img: /data/lfw/Art_Hoffmann/Art_Hoffmann_0002.jpg
# Img: /data/lfw/Boris_Becker/Boris_Becker_0006.jpg
# Img: /data/lfw/Kjell_Magne_Bondevik/Kjell_Magne_Bondevik_0003.jpg
# Img: /data/lfw/Hugo_Chavez/Hugo_Chavez_0042.jpg
# Img: /data/lfw/Carla_Del_Ponte/Carla_Del_Ponte_0005.jpg
# Img: /data/lfw/Leland_Chapman/Leland_Chapman_0001.jpg
# Img: /data/lfw/Susan_Sarandon/Susan_Sarandon_0005.jpg
# Img: /data/lfw/Megan_Mullally/Megan_Mullally_0003.jpg
# Img: /data/lfw/Ariel_Sharon/Ariel_Sharon_0060.jpg
# Img: /data/lfw/Carlos_Menem/Carlos_Menem_0008.jpg
# Img: /data/lfw/Mohamed_ElBaradei/Mohamed_ElBaradei_0006.jpg
# Img: /data/lfw/Richard_Dreyfuss/Richard_Dreyfuss_0001.jpg
# Img: /data/lfw/Robert_Mueller/Robert_Mueller_0005.jpg
# Img: /data/lfw/Norah_Jones/Norah_Jones_0011.jpg
# Img: /data/lfw/Francisco_Flores/Francisco_Flores_0003.jpg
# Img: /data/lfw/Colin_Jackson/Colin_Jackson_0001.jpg
# Img: /data/lfw/Luiz_Inacio_Lula_da_Silva/Luiz_Inacio_Lula_da_Silva_0048.jpg
# Img: /data/lfw/Bobby_Kielty/Bobby_Kielty_0001.jpg
# Img: /data/lfw/Halle_Berry/Halle_Berry_0016.jpg
# Img: /data/lfw/Emily_Robison/Emily_Robison_0002.jpg
# Img: /data/lfw/John_Ashcroft/John_Ashcroft_0053.jpg
# Img: /data/lfw/Carla_Del_Ponte/Carla_Del_Ponte_0004.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0098.jpg
# Img: /data/lfw/George_Clooney/George_Clooney_0004.jpg
# Img: /data/lfw/Charlton_Heston/Charlton_Heston_0003.jpg
# Img: /data/lfw/Jennifer_Capriati/Jennifer_Capriati_0016.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0019.jpg
# Img: /data/lfw/Lance_Armstrong/Lance_Armstrong_0002.jpg
# Img: /data/lfw/Tom_McClintock/Tom_McClintock_0001.jpg
# Img: /data/lfw/Benjamin_Netanyahu/Benjamin_Netanyahu_0005.jpg
# Img: /data/lfw/Jean_Charest/Jean_Charest_0003.jpg
# Img: /data/lfw/Javier_Solana/Javier_Solana_0004.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0094.jpg
# Img: /data/lfw/Zumrati_Juma/Zumrati_Juma_0001.jpg
# Img: /data/lfw/Se_Hyuk_Joo/Se_Hyuk_Joo_0001.jpg
# Img: /data/lfw/Tonga/Tonga_0001.jpg
# Img: /data/lfw/Lleyton_Hewitt/Lleyton_Hewitt_0015.jpg
# Img: /data/lfw/Tim_Allen/Tim_Allen_0003.jpg
# Img: /data/lfw/Rudi_Voeller/Rudi_Voeller_0001.jpg
# Img: /data/lfw/Mercedes_Amor/Mercedes_Amor_0001.jpg
# Img: /data/lfw/Stacy_Dragila/Stacy_Dragila_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0185.jpg
# Img: /data/lfw/Saddam_Hussein/Saddam_Hussein_0020.jpg
# Img: /data/lfw/Kofi_Annan/Kofi_Annan_0019.jpg
# Img: /data/lfw/Nancy_Reagan/Nancy_Reagan_0002.jpg
# Img: /data/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0009.jpg
# Img: /data/lfw/Adam_Scott/Adam_Scott_0001.jpg
# Img: /data/lfw/Luiz_Inacio_Lula_da_Silva/Luiz_Inacio_Lula_da_Silva_0027.jpg
# Img: /data/lfw/Wolfgang_Schuessel/Wolfgang_Schuessel_0001.jpg
# Img: /data/lfw/Janice_Goldfinger/Janice_Goldfinger_0001.jpg
# Img: /data/lfw/Gary_Doer/Gary_Doer_0001.jpg
# Img: /data/lfw/Steve_Phillips/Steve_Phillips_0001.jpg
# Img: /data/lfw/Kenny_Brack/Kenny_Brack_0001.jpg
# Img: /data/lfw/Bill_Hughes/Bill_Hughes_0001.jpg
# Img: /data/lfw/Syed_Ibrahim/Syed_Ibrahim_0001.jpg
# Img: /data/lfw/Ali_Fallahian/Ali_Fallahian_0001.jpg
# Img: /data/lfw/Erin_Runnion/Erin_Runnion_0001.jpg
# Img: /data/lfw/Nora_Bendijo/Nora_Bendijo_0001.jpg
# Img: /data/lfw/Ben_Betts/Ben_Betts_0001.jpg
# Img: /data/lfw/Jack_Straw/Jack_Straw_0028.jpg
# Img: /data/lfw/Justine_Pasek/Justine_Pasek_0007.jpg
# Img: /data/lfw/Pedro_Malan/Pedro_Malan_0005.jpg
# Img: /data/lfw/Sharess_Harrell/Sharess_Harrell_0001.jpg
# Img: /data/lfw/Annette_Bening/Annette_Bening_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0117.jpg
# Img: /data/lfw/Tommy_Franks/Tommy_Franks_0003.jpg
# Img: /data/lfw/Gerald_Fitch/Gerald_Fitch_0001.jpg
# Img: /data/lfw/Mahmoud_Abbas/Mahmoud_Abbas_0014.jpg
# Img: /data/lfw/Saddam_Hussein/Saddam_Hussein_0014.jpg
# Img: /data/lfw/Kenneth_Carlsen/Kenneth_Carlsen_0001.jpg
# Img: /data/lfw/Hilary_Duff/Hilary_Duff_0001.jpg
# Img: /data/lfw/Andy_Benes/Andy_Benes_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0285.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0079.jpg
# Img: /data/lfw/Tim_Matheson/Tim_Matheson_0001.jpg
# Img: /data/lfw/Jim_Harrick/Jim_Harrick_0001.jpg
# Img: /data/lfw/Alejandro_Toledo/Alejandro_Toledo_0005.jpg
# Img: /data/lfw/Marieta_Chrousala/Marieta_Chrousala_0001.jpg
# Img: /data/lfw/Hamid_Karzai/Hamid_Karzai_0019.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0191.jpg
# Img: /data/lfw/Tom_Ridge/Tom_Ridge_0030.jpg
# Img: /data/lfw/Mariah_Carey/Mariah_Carey_0006.jpg
# Img: /data/lfw/Martha_Smith/Martha_Smith_0001.jpg
# Img: /data/lfw/Mahendra_Chaudhry/Mahendra_Chaudhry_0001.jpg
# Img: /data/lfw/Celine_Dion/Celine_Dion_0003.jpg
# Img: /data/lfw/Wolfgang_Becker/Wolfgang_Becker_0001.jpg
# Img: /data/lfw/Aaron_Peirsol/Aaron_Peirsol_0002.jpg
# Img: /data/lfw/Catherine_Woodard/Catherine_Woodard_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0451.jpg
# Img: /data/lfw/Shimon_Peres/Shimon_Peres_0001.jpg
# Img: /data/lfw/Kofi_Annan/Kofi_Annan_0014.jpg
# Img: /data/lfw/Sepp_Blatter/Sepp_Blatter_0002.jpg
# Img: /data/lfw/Goldie_Hawn/Goldie_Hawn_0005.jpg
# Img: /data/lfw/Amy_Pascal/Amy_Pascal_0001.jpg
# Img: /data/lfw/David_Anderson/David_Anderson_0004.jpg
# Img: /data/lfw/Junichiro_Koizumi/Junichiro_Koizumi_0038.jpg
# Img: /data/lfw/King_Gyanendra/King_Gyanendra_0001.jpg
# Img: /data/lfw/Larry_Thompson/Larry_Thompson_0004.jpg
# Img: /data/lfw/Saddam_Hussein/Saddam_Hussein_0022.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0449.jpg
# Img: /data/lfw/Pascal_Lamy/Pascal_Lamy_0002.jpg
# Img: /data/lfw/Olivia_Newton-John/Olivia_Newton-John_0002.jpg
# Img: /data/lfw/Angelina_Jolie/Angelina_Jolie_0014.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0092.jpg
# Img: /data/lfw/Jeb_Bush/Jeb_Bush_0006.jpg
# Img: /data/lfw/Antonio_Catania/Antonio_Catania_0001.jpg
# Img: /data/lfw/Colleen_Ryan/Colleen_Ryan_0001.jpg
# Img: /data/lfw/Alexandra_Vodjanikova/Alexandra_Vodjanikova_0001.jpg
# Img: /data/lfw/Kim_Dae-jung/Kim_Dae-jung_0008.jpg
# Img: /data/lfw/Cameron_Diaz/Cameron_Diaz_0001.jpg
# Img: /data/lfw/Frank_Griswold/Frank_Griswold_0002.jpg
# Img: /data/lfw/Richard_Armitage/Richard_Armitage_0007.jpg
# Img: /data/lfw/Ed_Smart/Ed_Smart_0002.jpg
# Img: /data/lfw/Igor_Ivanov/Igor_Ivanov_0018.jpg
# Img: /data/lfw/Blas_Ople/Blas_Ople_0001.jpg
# Img: /data/lfw/Jean_Todt/Jean_Todt_0001.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0044.jpg
# Img: /data/lfw/Dan_Dickau/Dan_Dickau_0001.jpg
# Img: /data/lfw/Ricardo_Lagos/Ricardo_Lagos_0004.jpg
# Img: /data/lfw/Christina_Sawaya/Christina_Sawaya_0001.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0096.jpg
# Img: /data/lfw/Hugh_Grant/Hugh_Grant_0009.jpg
# Img: /data/lfw/Helen_Darling/Helen_Darling_0001.jpg
# Img: /data/lfw/Michelle_Rodriguez/Michelle_Rodriguez_0001.jpg
# Img: /data/lfw/Stephen_Arigbabu/Stephen_Arigbabu_0001.jpg
# Img: /data/lfw/Sigourney_Weaver/Sigourney_Weaver_0001.jpg
# Img: /data/lfw/Ilan_Ramon/Ilan_Ramon_0001.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0131.jpg
# Img: /data/lfw/Tina_Sinatra/Tina_Sinatra_0001.jpg
# Img: /data/lfw/Coco_dEste/Coco_dEste_0001.jpg
# Img: /data/lfw/Peter_Fisher/Peter_Fisher_0001.jpg
# Img: /data/lfw/Kalid_Kaid/Kalid_Kaid_0001.jpg
# Img: /data/lfw/Michael_Chiklis/Michael_Chiklis_0001.jpg
# Img: /data/lfw/Robert_Zoellick/Robert_Zoellick_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0081.jpg
# Img: /data/lfw/Michael_Linscott/Michael_Linscott_0001.jpg
# Img: /data/lfw/Tom_Cruise/Tom_Cruise_0004.jpg
# Img: /data/lfw/Megawati_Sukarnoputri/Megawati_Sukarnoputri_0020.jpg
# Img: /data/lfw/Faye_Dunaway/Faye_Dunaway_0001.jpg
# Img: /data/lfw/Renee_Zellweger/Renee_Zellweger_0013.jpg
# Img: /data/lfw/Matthew_Broderick/Matthew_Broderick_0001.jpg
# Img: /data/lfw/Eddy_Merckx/Eddy_Merckx_0001.jpg
# Img: /data/lfw/Jimmy_Jimenez/Jimmy_Jimenez_0001.jpg
# Img: /data/lfw/Matthew_During/Matthew_During_0001.jpg
# Img: /data/lfw/Lane_Odom/Lane_Odom_0001.jpg
# Img: /data/lfw/Rudolph_Giuliani/Rudolph_Giuliani_0018.jpg
# Img: /data/lfw/Gene_Robinson/Gene_Robinson_0005.jpg
# Img: /data/lfw/Jean_Chretien/Jean_Chretien_0005.jpg
# Img: /data/lfw/Sean_Astin/Sean_Astin_0003.jpg
# Img: /data/lfw/Gil_de_Ferran/Gil_de_Ferran_0001.jpg
# Img: /data/lfw/Howard_Dean/Howard_Dean_0006.jpg
# Img: /data/lfw/John_Ashcroft/John_Ashcroft_0041.jpg
# Img: /data/lfw/Manuel_Pellegrini/Manuel_Pellegrini_0001.jpg
# Img: /data/lfw/Jean_Chretien/Jean_Chretien_0019.jpg
# Img: /data/lfw/Chyung_Dai-chul/Chyung_Dai-chul_0001.jpg
# Img: /data/lfw/Jenny_Romero/Jenny_Romero_0001.jpg
# Img: /data/lfw/Joe_Lieberman/Joe_Lieberman_0007.jpg
# Img: /data/lfw/Julia_Tymoshenko/Julia_Tymoshenko_0002.jpg
# Img: /data/lfw/Pedro_Almodovar/Pedro_Almodovar_0001.jpg
# Img: /data/lfw/Robert_Torricelli/Robert_Torricelli_0002.jpg
# Img: /data/lfw/Ben_Affleck/Ben_Affleck_0003.jpg
# Img: /data/lfw/Kim_Clijsters/Kim_Clijsters_0003.jpg
# Img: /data/lfw/Marina_Hands/Marina_Hands_0001.jpg
# Img: /data/lfw/Halle_Berry/Halle_Berry_0015.jpg
# Img: /data/lfw/Michael_Killeen/Michael_Killeen_0001.jpg
# Img: /data/lfw/Nick_Rimando/Nick_Rimando_0001.jpg
# Img: /data/lfw/Alvaro_Uribe/Alvaro_Uribe_0031.jpg
# Img: /data/lfw/Alimzhan_Tokhtakhounov/Alimzhan_Tokhtakhounov_0001.jpg
# Img: /data/lfw/Dominique_de_Villepin/Dominique_de_Villepin_0002.jpg
# Img: /data/lfw/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0042.jpg
# Img: /data/lfw/Lori_Berenson/Lori_Berenson_0001.jpg
# Img: /data/lfw/Mary_Tyler_Moore/Mary_Tyler_Moore_0001.jpg
# Img: /data/lfw/Tom_Curley/Tom_Curley_0001.jpg
# Img: /data/lfw/Nabil_Shaath/Nabil_Shaath_0001.jpg
# Img: /data/lfw/John_Snow/John_Snow_0005.jpg
# Img: /data/lfw/Jack_Straw/Jack_Straw_0007.jpg
# Img: /data/lfw/Jean_Chretien/Jean_Chretien_0055.jpg
# Img: /data/lfw/Kim_Dae-jung/Kim_Dae-jung_0007.jpg
# Img: /data/lfw/Joe_Carnahan/Joe_Carnahan_0001.jpg
# Img: /data/lfw/Pierce_Brosnan/Pierce_Brosnan_0004.jpg
# Img: /data/lfw/Leonid_Kuchma/Leonid_Kuchma_0001.jpg
# Img: /data/lfw/Adam_Sandler/Adam_Sandler_0001.jpg
# Img: /data/lfw/Katalin_Kollat/Katalin_Kollat_0001.jpg
# Img: /data/lfw/Eugene_Melnyk/Eugene_Melnyk_0001.jpg
# Img: /data/lfw/Lindsay_Davenport/Lindsay_Davenport_0014.jpg
# Img: /data/lfw/Rick_Husband/Rick_Husband_0001.jpg
# Img: /data/lfw/Infanta_Cristina/Infanta_Cristina_0001.jpg
# Img: /data/lfw/Flavia_Pennetta/Flavia_Pennetta_0001.jpg
# Img: /data/lfw/Salma_Hayek/Salma_Hayek_0010.jpg
# Img: /data/lfw/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0025.jpg
# Img: /data/lfw/Hugo_Colace/Hugo_Colace_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_
0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0454.jpg
# Img: /data/lfw/Hu_Jintao/Hu_Jintao_0001.jpg
# Img: /data/lfw/Michael_Patrick_King/Michael_Patrick_King_0001.jpg
# Img: /data/lfw/Steve_Blake/Steve_Blake_0001.jpg
# Img: /data/lfw/Biljana_Plavsic/Biljana_Plavsic_0002.jpg
# Img: /data/lfw/Pedro_Solbes/Pedro_Solbes_0004.jpg
# Img: /data/lfw/Gregory_Hines/Gregory_Hines_0001.jpg
# Img: /data/lfw/Doug_Moe/Doug_Moe_0001.jpg
# Img: /data/lfw/Xanana_Gusmao/Xanana_Gusmao_0005.jpg
# Img: /data/lfw/Bill_Clinton/Bill_Clinton_0020.jpg
# Img: /data/lfw/Erika_Harold/Erika_Harold_0002.jpg
# Img: /data/lfw/Kevin_Satterfield/Kevin_Satterfield_0001.jpg
# Img: /data/lfw/Cruz_Bustamante/Cruz_Bustamante_0005.jpg
# Img: /data/lfw/Jean_Chretien/Jean_Chretien_0037.jpg
# Img: /data/lfw/Frank_Cassell/Frank_Cassell_0001.jpg
# Img: /data/lfw/Igor_Ivanov/Igor_Ivanov_0013.jpg
# Img: /data/lfw/Jean_Chretien/Jean_Chretien_0036.jpg
# Img: /data/lfw/Steven_Hatfill/Steven_Hatfill_0002.jpg
# Img: /data/lfw/Jorge_Castaneda/Jorge_Castaneda_0001.jpg
# Img: /data/lfw/John_Ferguson/John_Ferguson_0001.jpg
# Img: /data/lfw/Bob_Hope/Bob_Hope_0003.jpg
# Img: /data/lfw/Parris_Glendening/Parris_Glendening_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0418.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0097.jpg
# Img: /data/lfw/Bill_Frist/Bill_Frist_0007.jpg
# Img: /data/lfw/Candice_Bergen/Candice_Bergen_0003.jpg
# Img: /data/lfw/Leszek_Miller/Leszek_Miller_0003.jpg
# Img: /data/lfw/Justin_Timberlake/Justin_Timberlake_0008.jpg
# Img: /data/lfw/Woody_Allen/Woody_Allen_0004.jpg
# Img: /data/lfw/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0039.jpg
# Img: /data/lfw/Heather_Mills/Heather_Mills_0002.jpg
# Img: /data/lfw/David_Heyman/David_Heyman_0002.jpg
# Img: /data/lfw/Fidel_Castro/Fidel_Castro_0003.jpg
# Img: /data/lfw/Ben_Braun/Ben_Braun_0001.jpg
# Img: /data/lfw/Mike_Matheny/Mike_Matheny_0001.jpg
# Img: /data/lfw/Joan_Laporta/Joan_Laporta_0005.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0423.jpg
# Img: /data/lfw/Guy_Hemmings/Guy_Hemmings_0001.jpg
# Img: /data/lfw/Bill_Frist/Bill_Frist_0008.jpg
# Img: /data/lfw/Heath_Ledger/Heath_Ledger_0003.jpg
# Img: /data/lfw/Kristen_Breitweiser/Kristen_Breitweiser_0002.jpg
# Img: /data/lfw/Stanley_McChrystal/Stanley_McChrystal_0003.jpg
# Img: /data/lfw/Naomi_Hayashi/Naomi_Hayashi_0001.jpg
# Img: /data/lfw/Bob_Taft/Bob_Taft_0001.jpg
# Img: /data/lfw/Jaouad_Gharib/Jaouad_Gharib_0001.jpg
# Img: /data/lfw/John_Negroponte/John_Negroponte_0006.jpg
# Img: /data/lfw/Molly_Sims/Molly_Sims_0001.jpg
# Img: /data/lfw/Drew_Barrymore/Drew_Barrymore_0001.jpg
# Img: /data/lfw/Alex_Sink/Alex_Sink_0003.jpg
# Img: /data/lfw/Ariel_Sharon/Ariel_Sharon_0010.jpg
# Img: /data/lfw/Tom_Cruise/Tom_Cruise_0008.jpg
# Img: /data/lfw/Larry_Eustachy/Larry_Eustachy_0001.jpg
# Img: /data/lfw/Vicente_Fernandez/Vicente_Fernandez_0003.jpg
# Img: /data/lfw/Bill_Clinton/Bill_Clinton_0015.jpg
# Img: /data/lfw/Kamal_Kharrazi/Kamal_Kharrazi_0004.jpg
# Img: /data/lfw/Ann_Veneman/Ann_Veneman_0004.jpg
# Img: /data/lfw/Erika_Harold/Erika_Harold_0001.jpg
# Img: /data/lfw/Robbie_Williams/Robbie_Williams_0003.jpg
# Img: /data/lfw/Roger_Daltrey/Roger_Daltrey_0001.jpg
# Img: /data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0001.jpg
# Img: /data/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0013.jpg
# Img: /data/lfw/John_Sweeney/John_Sweeney_0001.jpg
# Img: /data/lfw/Brandon_Inge/Brandon_Inge_0001.jpg
# Img: /data/lfw/Mark_Cuban/Mark_Cuban_0001.jpg
# Img: /data/lfw/Bill_Sizemore/Bill_Sizemore_0002.jpg
# Img: /data/lfw/Arnold_Schwarzenegger/Arnold_Schwarzenegger_0014.jpg
# Img: /data/lfw/Anil_Ramsook/Anil_Ramsook_0001.jpg
# Img: /data/lfw/Christy_Ferer/Christy_Ferer_0001.jpg
# Img: /data/lfw/Viara_Vike-Freiberga/Viara_Vike-Freiberga_0001.jpg
# Img: /data/lfw/Robert_Stack/Robert_Stack_0001.jpg
# Img: /data/lfw/Donald_Anderson/Donald_Anderson_0001.jpg
# Img: /data/lfw/Tony_Shalhoub/Tony_Shalhoub_0001.jpg
# Img: /data/lfw/Daisy_Fuentes/Daisy_Fuentes_0002.jpg
# Img: /data/lfw/Yasar_Yakis/Yasar_Yakis_0004.jpg
# Img: /data/lfw/John_Snow/John_Snow_0014.jpg
# Img: /data/lfw/Nina_Jacobson/Nina_Jacobson_0001.jpg
# Img: /data/lfw/Jude_Law/Jude_Law_0001.jpg
# Img: /data/lfw/Wayne_Ferreira/Wayne_Ferreira_0005.jpg
# Img: /data/lfw/Walt_Harris/Walt_Harris_0001.jpg
# Img: /data/lfw/Jose_Maria_Aznar/Jose_Maria_Aznar_0016.jpg
# Img: /data/lfw/Kevin_Costner/Kevin_Costner_0008.jpg
# Img: /data/lfw/Patricia_Phillips/Patricia_Phillips_0001.jpg
# Img: /data/lfw/Hu_Jintao/Hu_Jintao_0003.jpg
# Img: /data/lfw/Jake_Gyllenhaal/Jake_Gyllenhaal_0002.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0158.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0184.jpg
# Img: /data/lfw/Silvio_Berlusconi/Silvio_Berlusconi_0029.jpg
# Img: /data/lfw/Julio_Cesar_Franco/Julio_Cesar_Franco_0001.jpg
# Img: /data/lfw/Donald_Rumsfeld/Donald_Rumsfeld_0068.jpg
# Img: /data/lfw/George_Allen/George_Allen_0001.jpg
# Img: /data/lfw/Pieter_Bouw/Pieter_Bouw_0001.jpg
# Img: /data/lfw/Bill_Readdy/Bill_Readdy_0001.jpg
# Img: /data/lfw/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0010.jpg
# Img: /data/lfw/Wilson_Alvarez/Wilson_Alvarez_0001.jpg
# Img: /data/lfw/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0003.jpg
# Img: /data/lfw/Richard_Myers/Richard_Myers_0001.jpg
# Img: /data/lfw/Nia_Vardalos/Nia_Vardalos_0002.jpg
# Img: /data/lfw/Michael_Haneke/Michael_Haneke_0001.jpg
# Img: /data/lfw/Terje_Roed-Larsen/Terje_Roed-Larsen_0002.jpg
# Img: /data/lfw/Alonzo_Mourning/Alonzo_Mourning_0001.jpg
# Img: /data/lfw/Luis_Figo/Luis_Figo_0003.jpg
# Img: /data/lfw/Osama_bin_Laden/Osama_bin_Laden_0004.jpg
# Img: /data/lfw/Robert_De_Niro/Robert_De_Niro_0006.jpg
# Img: /data/lfw/Bijan_Darvish/Bijan_Darvish_0003.jpg
# Img: /data/lfw/Angelo_Reyes/Angelo_Reyes_0004.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0088.jpg
# Img: /data/lfw/Chris_Matthews/Chris_Matthews_0001.jpg
# Img: /data/lfw/Jan_van_Breda_Kolff/Jan_van_Breda_Kolff_0001.jpg
# Img: /data/lfw/Muhammad_Ali/Muhammad_Ali_0010.jpg
# Img: /data/lfw/Ariel_Sharon/Ariel_Sharon_0002.jpg
# Img: /data/lfw/Rene_Portland/Rene_Portland_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0489.jpg
# Img: /data/lfw/Iran_Brown/Iran_Brown_0001.jpg
# Img: /data/lfw/Ari_Bousbib/Ari_Bousbib_0001.jpg
# Img: /data/lfw/Mary_Descenza/Mary_Descenza_0001.jpg
# Img: /data/lfw/Roger_Grimes/Roger_Grimes_0001.jpg
# Img: /data/lfw/Michael_Moore/Michael_Moore_0001.jpg
# Img: /data/lfw/Tony_Shalhoub/Tony_Shalhoub_0002.jpg
# Img: /data/lfw/Ariel_Sharon/Ariel_Sharon_0019.jpg
# Img: /data/lfw/Gil_Cates/Gil_Cates_0001.jpg
# Img: /data/lfw/Yasser_Arafat/Yasser_Arafat_0006.jpg
# Img: /data/lfw/Charles_Pickering/Charles_Pickering_0001.jpg
# Img: /data/lfw/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0024.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0190.jpg
# Img: /data/lfw/Keanu_Reeves/Keanu_Reeves_0009.jpg
# Img: /data/lfw/Bertrand_Bonello/Bertrand_Bonello_0001.jpg
# Img: /data/lfw/Richard_Gere/Richard_Gere_0004.jpg
# Img: /data/lfw/Saddam_Hussein/Saddam_Hussein_0003.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0042.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0087.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0194.jpg
# Img: /data/lfw/John_Negroponte/John_Negroponte_0015.jpg
# Img: /data/lfw/Rio_Ferdinand/Rio_Ferdinand_0002.jpg
# Img: /data/lfw/Karin_Stoiber/Karin_Stoiber_0002.jpg
# Img: /data/lfw/David_Brent/David_Brent_0001.jpg
# Img: /data/lfw/Phil_Bennett/Phil_Bennett_0001.jpg
# Img: /data/lfw/William_Hochul/William_Hochul_0002.jpg
# Img: /data/lfw/Marcelo_Salas/Marcelo_Salas_0001.jpg
# Img: /data/lfw/Jennifer_Aniston/Jennifer_Aniston_0007.jpg
# Img: /data/lfw/Tina_Conner/Tina_Conner_0001.jpg
# Img: /data/lfw/Marcelo_Ebrard/Marcelo_Ebrard_0003.jpg
# Img: /data/lfw/Saddam_Hussein/Saddam_Hussein_0013.jpg
# Img: /data/lfw/Lindsay_Davenport/Lindsay_Davenport_0011.jpg
# Img: /data/lfw/Albaro_Recoba/Albaro_Recoba_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0427.jpg
# Img: /data/lfw/Russell_Simmons/Russell_Simmons_0002.jpg
# Img: /data/lfw/Guillermo_Coria/Guillermo_Coria_0006.jpg
# Img: /data/lfw/Vicente_Fox/Vicente_Fox_0008.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0126.jpg
# Img: /data/lfw/Edward_Kennedy/Edward_Kennedy_0002.jpg
# Img: /data/lfw/Queen_Elizabeth_II/Queen_Elizabeth_II_0007.jpg
# Img: /data/lfw/Jean-Patrick_Nazon/Jean-Patrick_Nazon_0001.jpg
# Img: /data/lfw/Rick_Barnes/Rick_Barnes_0001.jpg
# Img: /data/lfw/Jean-David_Levitte/Jean-David_Levitte_0004.jpg
# Img: /data/lfw/Martin_ONeill/Martin_ONeill_0001.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0086.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0422.jpg
# Img: /data/lfw/Giuseppe_Gibilisco/Giuseppe_Gibilisco_0003.jpg
# Img: /data/lfw/Tim_Robbins/Tim_Robbins_0003.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0274.jpg
# Img: /data/lfw/Augustin_Calleri/Augustin_Calleri_0002.jpg
# Img: /data/lfw/Antonio_Cassano/Antonio_Cassano_0001.jpg
# Img: /data/lfw/Tom_Reilly/Tom_Reilly_0001.jpg
# Img: /data/lfw/Brian_Gregory/Brian_Gregory_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0012.jpg
# Img: /data/lfw/Leszek_Miller/Leszek_Miller_0002.jpg
# Img: /data/lfw/Billy_Tibbets/Billy_Tibbets_0001.jpg
# Img: /data/lfw/Vladimir_Putin/Vladimir_Putin_0035.jpg
# Img: /data/lfw/Joe_Nichols/Joe_Nichols_0003.jpg
# Img: /data/lfw/Laurence_Fishburne/Laurence_Fishburne_0001.jpg
# Img: /data/lfw/Ricardo_Monasterio/Ricardo_Monasterio_0001.jpg
# Img: /data/lfw/Keith_Snyder/Keith_Snyder_0001.jpg
# Img: /data/lfw/Edmund_Stoiber/Edmund_Stoiber_0001.jpg
# Img: /data/lfw/Shawn_Marion/Shawn_Marion_0001.jpg
# Img: /data/lfw/Thomas_Fargo/Thomas_Fargo_0003.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0047.jpg
# Img: /data/lfw/Jean_Charest/Jean_Charest_0001.jpg
# Img: /data/lfw/Muhammad_Ali/Muhammad_Ali_0009.jpg
# Img: /data/lfw/Andre_Agassi/Andre_Agassi_0009.jpg
# Img: /data/lfw/Hugh_Grant/Hugh_Grant_0003.jpg
# Img: /data/lfw/Ian_Thorpe/Ian_Thorpe_0007.jpg
# Img: /data/lfw/Max_Mayfield/Max_Mayfield_0001.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0101.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0180.jpg
# Img: /data/lfw/Lea_Fastow/Lea_Fastow_0002.jpg
# Img: /data/lfw/Rand_Miller/Rand_Miller_0001.jpg
# Img: /data/lfw/Rudolph_Giuliani/Rudolph_Giuliani_0026.jpg
# Img: /data/lfw/Robin_Cook/Robin_Cook_0001.jpg
# Img: /data/lfw/Zoe_Ball/Zoe_Ball_0001.jpg
# Img: /data/lfw/Jeff_Bridges/Jeff_Bridges_0001.jpg
# Img: /data/lfw/Natalya_Sazanovich/Natalya_Sazanovich_0001.jpg
# Img: /data/lfw/Megawati_Sukarnoputri/Megawati_Sukarnoputri_0021.jpg
# Img: /data/lfw/John_Baldacci/John_Baldacci_0001.jpg
# Img: /data/lfw/Princess_Stephanie/Princess_Stephanie_0001.jpg
# Img: /data/lfw/Patricia_Clarkson/Patricia_Clarkson_0004.jpg
# Img: /data/lfw/Edward_Albee/Edward_Albee_0001.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0089.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0442.jpg
# Img: /data/lfw/Arnaud_Clement/Arnaud_Clement_0002.jpg
# Img: /data/lfw/Alecos_Markides/Alecos_Markides_0001.jpg
# Img: /data/lfw/Adrien_Brody/Adrien_Brody_0002.jpg
# Img: /data/lfw/Jennifer_Capriati/Jennifer_Capriati_0036.jpg
# Img: /data/lfw/Nicolas_Cage/Nicolas_Cage_0004.jpg
# Img: /data/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0001.jpg
# Img: /data/lfw/Tony_Blair/Tony_Blair_0036.jpg
# Img: /data/lfw/Mike_Leach/Mike_Leach_0001.jpg
# Img: /data/lfw/Emma_Watson/Emma_Watson_0002.jpg
# Img: /data/lfw/Queen_Elizabeth_II/Queen_Elizabeth_II_0009.jpg
# Img: /data/lfw/Donald_Rumsfeld/Donald_Rumsfeld_0062.jpg
# Img: /data/lfw/Sergio_Vieira_De_Mello/Sergio_Vieira_De_Mello_0007.jpg
# Img: /data/lfw/Kim_Jong-Il/Kim_Jong-Il_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0180.jpg
# Img: /data/lfw/Al_Pacino/Al_Pacino_0003.jpg
# Img: /data/lfw/Mireya_Moscoso/Mireya_Moscoso_0004.jpg
# Img: /data/lfw/Robert_De_Niro/Robert_De_Niro_0002.jpg
# Img: /data/lfw/Troy_Hudson/Troy_Hudson_0001.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0213.jpg
# Img: /data/lfw/Huang_Suey-Sheng/Huang_Suey-Sheng_0001.jpg
# Img: /data/lfw/Pedro_Almodovar/Pedro_Almodovar_0002.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0414.jpg
# Img: /data/lfw/Donald_Rumsfeld/Donald_Rumsfeld_0020.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0272.jpg
# Img: /data/lfw/Thierry_Falise/Thierry_Falise_0001.jpg
# Img: /data/lfw/Pervez_Musharraf/Pervez_Musharraf_0001.jpg
# Img: /data/lfw/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0008.jpg
# Img: /data/lfw/Jeb_Bush/Jeb_Bush_0003.jpg
# Img: /data/lfw/Aitor_Gonzalez/Aitor_Gonzalez_0001.jpg
# Img: /data/lfw/Naomi_Watts/Naomi_Watts_0015.jpg
# Img: /data/lfw/Kristanna_Loken/Kristanna_Loken_0001.jpg
# Img: /data/lfw/Dale_Earnhardt_Jr/Dale_Earnhardt_Jr_0002.jpg
# Img: /data/lfw/Pascal_Rheaume/Pascal_Rheaume_0001.jpg
# Img: /data/lfw/Tom_Daschle/Tom_Daschle_0006.jpg
# Img: /data/lfw/Marco_Antonio_Barrera/Marco_Antonio_Barrera_0006.jpg
# Img: /data/lfw/Justin_Timberlake/Justin_Timberlake_0007.jpg
# Img: /data/lfw/John_Wayne/John_Wayne_0001.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0211.jpg
# Img: /data/lfw/Holly_Hunter/Holly_Hunter_0004.jpg
# Img: /data/lfw/Bill_Paxton/Bill_Paxton_0002.jpg
# Img: /data/lfw/Sergei_Ivanov/Sergei_Ivanov_0003.jpg
# Img: /data/lfw/Harry_Schmidt/Harry_Schmidt_0002.jpg
# Img: /data/lfw/Nestor_Kirchner/Nestor_Kirchner_0015.jpg
# Img: /data/lfw/Jack_Straw/Jack_Straw_0026.jpg
# Img: /data/lfw/David_Sousa/David_Sousa_0001.jpg
# Img: /data/lfw/Jennifer_Capriati/Jennifer_Capriati_0023.jpg
# Img: /data/lfw/Christopher_Whittle/Christopher_Whittle_0001.jpg
# Img: /data/lfw/Queen_Beatrix/Queen_Beatrix_0002.jpg
# Img: /data/lfw/Ariel_Sharon/Ariel_Sharon_0011.jpg
# Img: /data/lfw/Felix_Mantilla/Felix_Mantilla_0002.jpg
# Img: /data/lfw/Hu_Jintao/Hu_Jintao_0002.jpg
# Img: /data/lfw/Jose_Canseco/Jose_Canseco_0003.jpg
# Img: /data/lfw/Juan_Valencia_Osorio/Juan_Valencia_Osorio_0001.jpg
# Img: /data/lfw/Sarah_Price/Sarah_Price_0001.jpg
# Img: /data/lfw/Aaron_Patterson/Aaron_Patterson_0001.jpg
# Img: /data/lfw/Pat_Wharton/Pat_Wharton_0001.jpg
# Img: /data/lfw/Colin_Montgomerie/Colin_Montgomerie_0005.jpg
# Img: /data/lfw/Marty_Mornhinweg/Marty_Mornhinweg_0003.jpg
# Img: /data/lfw/Larry_Wilmore/Larry_Wilmore_0001.jpg
# Img: /data/lfw/Edward_Lu/Edward_Lu_0006.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0038.jpg
# Img: /data/lfw/Chuck_Amato/Chuck_Amato_0002.jpg
# Img: /data/lfw/Art_Howe/Art_Howe_0001.jpg
# Img: /data/lfw/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0005.jpg
# Img: /data/lfw/Sergio_Garcia/Sergio_Garcia_0002.jpg
# Img: /data/lfw/Bob_Wright/Bob_Wright_0001.jpg
# Img: /data/lfw/David_Millar/David_Millar_0001.jpg
# Img: /data/lfw/Elizabeth_Smart/Elizabeth_Smart_0002.jpg
# Img: /data/lfw/Yoo_Jay-Kun/Yoo_Jay-Kun_0001.jpg
# Img: /data/lfw/Ron_Dittemore/Ron_Dittemore_0001.jpg
# Img: /data/lfw/Linda_Ham/Linda_Ham_0001.jpg
# Img: /data/lfw/Alex_Holmes/Alex_Holmes_0001.jpg
# Img: /data/lfw/Catherine_Donkers/Catherine_Donkers_0001.jpg
# Img: /data/lfw/Russell_Coutts/Russell_Coutts_0001.jpg
# Img: /data/lfw/Laila_Ali/Laila_Ali_0001.jpg
# Img: /data/lfw/David_Dewhurst/David_Dewhurst_0001.jpg
# Img: /data/lfw/Chung_Mong-hun/Chung_Mong-hun_0002.jpg
# Img: /data/lfw/Fernando_Henrique_Cardoso/Fernando_Henrique_Cardoso_0004.jpg
# Img: /data/lfw/Askar_Akayev/Askar_Akayev_0001.jpg
# Img: /data/lfw/Roy_Moore/Roy_Moore_0003.jpg
# Img: /data/lfw/Claudia_Pechstein/Claudia_Pechstein_0005.jpg
# Img: /data/lfw/Catherine_Deneuve/Catherine_Deneuve_0004.jpg
# Img: /data/lfw/Ken_Kutaragi/Ken_Kutaragi_0001.jpg
# Img: /data/lfw/Erika_Reyes/Erika_Reyes_0001.jpg
# Img: /data/lfw/Osama_bin_Laden/Osama_bin_Laden_0003.jpg
# Img: /data/lfw/Peter_Medgyessy/Peter_Medgyessy_0001.jpg
# Img: /data/lfw/Tavis_Smiley/Tavis_Smiley_0001.jpg
# Img: /data/lfw/Jonathan_Schroeder/Jonathan_Schroeder_0001.jpg
# Img: /data/lfw/Christian_Olsson/Christian_Olsson_0001.jpg
# Img: /data/lfw/Kalpana_Chawla/Kalpana_Chawla_0003.jpg
# Img: /data/lfw/Peter_Goldmark/Peter_Goldmark_0001.jpg
# Img: /data/lfw/Gordon_Brown/Gordon_Brown_0009.jpg
# Img: /data/lfw/Dan_Duquette/Dan_Duquette_0001.jpg
# Img: /data/lfw/Lawrence_Vito/Lawrence_Vito_0001.jpg
# Img: /data/lfw/George_W_Bush/George_W_Bush_0378.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0042.jpg
# Img: /data/lfw/Wolfgang_Clement/Wolfgang_Clement_0001.jpg
# Img: /data/lfw/Gerhard_Schroeder/Gerhard_Schroeder_0071.jpg
# Img: /data/lfw/Daniela_Hantuchova/Daniela_Hantuchova_0001.jpg
# Img: /data/lfw/Mike_Price/Mike_Price_0001.jpg
# Img: /data/lfw/Elton_John/Elton_John_0007.jpg
# Img: /data/lfw/Bulent_Ecevit/Bulent_Ecevit_0002.jpg
# Img: /data/lfw/Colin_Powell/Colin_Powell_0153.jpg
# Img: /data/lfw/Ed_Rosenthal/Ed_Rosenthal_0003.jpg
# Img: /data/lfw/Pauline_Phillips/Pauline_Phillips_0001.jpg
# Img: /data/lfw/Kim_Ryong-sung/Kim_Ryong-sung_0001.jpg
# ...
# Img: /data/dog_images/train/129.Tibetan_mastiff/Tibetan_mastiff_08133.jpg
# Img: /data/dog_images/train/023.Bernese_mountain_dog/Bernese_mountain_dog_01683.jpg
# Img: /data/dog_images/train/034.Boxer/Boxer_02369.jpg
# Img: /data/dog_images/train/097.Lakeland_terrier/Lakeland_terrier_06547.jpg
# Img: /data/dog_images/train/087.Irish_terrier/Irish_terrier_05879.jpg
# Img: /data/dog_images/train/002.Afghan_hound/Afghan_hound_00119.jpg
# Img: /data/dog_images/train/036.Briard/Briard_02564.jpg
# Img: /data/dog_images/train/008.American_staffordshire_terrier/American_staffordshire_terrier_00574.jpg
# Img: /data/dog_images/train/021.Belgian_sheepdog/Belgian_sheepdog_01481.jpg
# Img: /data/dog_images/train/124.Poodle/Poodle_07918.jpg
# Img: /data/dog_images/train/086.Irish_setter/Irish_setter_05857.jpg
# Img: /data/dog_images/train/084.Icelandic_sheepdog/Icelandic_sheepdog_05747.jpg
# Img: /data/dog_images/train/113.Old_english_sheepdog/Old_english_sheepdog_07374.jpg
# Img: /data/dog_images/train/028.Bluetick_coonhound/Bluetick_coonhound_01974.jpg
# Img: /data/dog_images/train/108.Norwegian_buhund/Norwegian_buhund_07093.jpg
# Img: /data/dog_images/train/086.Irish_setter/Irish_setter_05841.jpg
# Img: /data/dog_images/train/083.Ibizan_hound/Ibizan_hound_05690.jpg
# Img: /data/dog_images/train/095.Kuvasz/Kuvasz_06428.jpg
# Img: /data/dog_images/train/097.Lakeland_terrier/Lakeland_terrier_06523.jpg
# Img: /data/dog_images/train/019.Bedlington_terrier/Bedlington_terrier_01372.jpg
# Img: /data/dog_images/train/054.Collie/Collie_03801.jpg
# Img: /data/dog_images/train/071.German_shepherd_dog/German_shepherd_dog_04888.jpg
# Img: /data/dog_images/train/043.Canaan_dog/Canaan_dog_03097.jpg
# Img: /data/dog_images/train/006.American_eskimo_dog/American_eskimo_dog_00396.jpg
# Img: /data/dog_images/train/030.Border_terrier/Border_terrier_02119.jpg
# Img: /data/dog_images/train/003.Airedale_terrier/Airedale_terrier_00167.jpg
# Img: /data/dog_images/train/031.Borzoi/Borzoi_02214.jpg
# Img: /data/dog_images/train/047.Chesapeake_bay_retriever/Chesapeake_bay_retriever_03334.jpg
# Img: /data/dog_images/train/026.Black_russian_terrier/Black_russian_terrier_01870.jpg
# Img: /data/dog_images/train/117.Pekingese/Pekingese_07565.jpg
# Img: /data/dog_images/train/029.Border_collie/Border_collie_02087.jpg
# Img: /data/dog_images/train/005.Alaskan_malamute/Alaskan_malamute_00374.jpg
# Img: /data/dog_images/train/039.Bull_terrier/Bull_terrier_02731.jpg
# Img: /data/dog_images/train/065.Entlebucher_mountain_dog/Entlebucher_mountain_dog_04598.jpg
# Img: /data/dog_images/train/057.Dalmatian/Dalmatian_04038.jpg
# Img: /data/dog_images/train/057.Dalmatian/Dalmatian_04087.jpg
# Img: /data/dog_images/train/011.Australian_cattle_dog/Australian_cattle_dog_00770.jpg
# Img: /data/dog_images/train/099.Lhasa_apso/Lhasa_apso_06662.jpg
# Img: /data/dog_images/train/097.Lakeland_terrier/Lakeland_terrier_06545.jpg
# Img: /data/dog_images/train/018.Beauceron/Beauceron_01327.jpg
# Img: /data/dog_images/train/036.Briard/Briard_02570.jpg
# Img: /data/dog_images/train/098.Leonberger/Leonberger_06616.jpg
# Img: /data/dog_images/train/062.English_setter/English_setter_04430.jpg
# Img: /data/dog_images/train/116.Parson_russell_terrier/Parson_russell_terrier_07544.jpg
# Img: /data/dog_images/train/060.Dogue_de_bordeaux/Dogue_de_bordeaux_04243.jpg
# Img: /data/dog_images/train/072.German_shorthaired_pointer/German_shorthaired_pointer_04978.jpg
# Img: /data/dog_images/train/039.Bull_terrier/Bull_terrier_02788.jpg
# Img: /data/dog_images/train/060.Dogue_de_bordeaux/Dogue_de_bordeaux_
058.Dandie_dinmont_terrier/Dandie_dinmont_terrier_04150.jpg
# Img: /data/dog_images/train/014.Basenji/Basenji_01002.jpg
# Img: /data/dog_images/train/076.Golden_retriever/Golden_retriever_05247.jpg
# Img: /data/dog_images/train/115.Papillon/Papillon_07492.jpg
# Img: /data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03739.jpg
# Img: /data/dog_images/train/103.Mastiff/Mastiff_06846.jpg
# Img: /data/dog_images/train/045.Cardigan_welsh_corgi/Cardigan_welsh_corgi_03213.jpg
# Img: /data/dog_images/train/084.Icelandic_sheepdog/Icelandic_sheepdog_05715.jpg
# Img: /data/dog_images/train/126.Saint_bernard/Saint_bernard_08034.jpg
# Img: /data/dog_images/train/016.Beagle/Beagle_01172.jpg
# Img: /data/dog_images/train/006.American_eskimo_dog/American_eskimo_dog_00438.jpg
# Img: /data/dog_images/train/016.Beagle/Beagle_01194.jpg
# Img: /data/dog_images/train/031.Borzoi/Borzoi_02169.jpg
# Img: /data/dog_images/train/006.American_eskimo_dog/American_eskimo_dog_00457.jpg
# Img: /data/dog_images/train/072.German_shorthaired_pointer/German_shorthaired_pointer_04982.jpg
# Img: /data/dog_images/train/123.Pomeranian/Pomeranian_07885.jpg
# Img: /data/dog_images/train/133.Yorkshire_terrier/Yorkshire_terrier_08332.jpg
# Img: /data/dog_images/train/133.Yorkshire_terrier/Yorkshire_terrier_08331.jpg
# Img: /data/dog_images/train/066.Field_spaniel/Field_spaniel_04609.jpg
# Img: /data/dog_images/train/017.Bearded_collie/Bearded_collie_01271.jpg
# Img: /data/dog_images/train/019.Bedlington_terrier/Bedlington_terrier_01354.jpg
# Img: /data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03921.jpg
# Img: /data/dog_images/train/075.Glen_of_imaal_terrier/Glen_of_imaal_terrier_05171.jpg
# Img: /data/dog_images/train/077.Gordon_setter/Gordon_setter_05299.jpg
# Img: /data/dog_images/train/013.Australian_terrier/Australian_terrier_00935.jpg
# Img: /data/dog_images/train/012.Australian_shepherd/Australian_shepherd_00858.jpg
# Img: /data/dog_images/train/017.Bearded_collie/Bearded_collie_01206.jpg
# Img: /data/dog_images/train/012.Australian_shepherd/Australian_shepherd_00846.jpg
# Img: /data/dog_images/train/100.Lowchen/Lowchen_06679.jpg
# Img: /data/dog_images/train/116.Parson_russell_terrier/Parson_russell_terrier_07542.jpg
# Img: /data/dog_images/train/049.Chinese_crested/Chinese_crested_03468.jpg
# Img: /data/dog_images/train/069.French_bulldog/French_bulldog_04791.jpg
# Img: /data/dog_images/train/093.Kerry_blue_terrier/Kerry_blue_terrier_06326.jpg
# Img: /data/dog_images/train/063.English_springer_spaniel/English_springer_spaniel_04482.jpg
# Img: /data/dog_images/train/086.Irish_setter/Irish_setter_05844.jpg
# Img: /data/dog_images/train/030.Border_terrier/Border_terrier_02152.jpg
# Img: /data/dog_images/train/118.Pembroke_welsh_corgi/Pembroke_welsh_corgi_07647.jpg
# Img: /data/dog_images/train/021.Belgian_sheepdog/Belgian_sheepdog_01545.jpg
# Img: /data/dog_images/train/026.Black_russian_terrier/Black_russian_terrier_01820.jpg
# Img: /data/dog_images/train/037.Brittany/Brittany_02608.jpg
# Img: /data/dog_images/train/068.Flat-coated_retriever/Flat-coated_retriever_04757.jpg
# Img: /data/dog_images/train/116.Parson_russell_terrier/Parson_russell_terrier_07551.jpg
# Img: /data/dog_images/train/084.Icelandic_sheepdog/Icelandic_sheepdog_05748.jpg
# Img: /data/dog_images/train/119.Petit_basset_griffon_vendeen/Petit_basset_griffon_vendeen_07701.jpg
# Img: /data/dog_images/train/021.Belgian_sheepdog/Belgian_sheepdog_01546.jpg
# Img: /data/dog_images/train/076.Golden_retriever/Golden_retriever_05207.jpg
# Img: /data/dog_images/train/060.Dogue_de_bordeaux/Dogue_de_bordeaux_04245.jpg
# Img: /data/dog_images/train/068.Flat-coated_retriever/Flat-coated_retriever_04710.jpg
# Img: /data/dog_images/train/018.Beauceron/Beauceron_01298.jpg
# Img: /data/dog_images/train/025.Black_and_tan_coonhound/Black_and_tan_coonhound_01815.jpg
# Img: /data/dog_images/train/096.Labrador_retriever/Labrador_retriever_06477.jpg
# Img: /data/dog_images/train/071.German_shepherd_dog/German_shepherd_dog_04904.jpg
# Img: /data/dog_images/train/016.Beagle/Beagle_01154.jpg
# Img: /data/dog_images/train/081.Greyhound/Greyhound_05522.jpg
# Img: /data/dog_images/train/009.American_water_spaniel/American_water_spaniel_00634.jpg
# Img: /data/dog_images/train/094.Komondor/Komondor_06348.jpg
# Img: /data/dog_images/train/008.American_staffordshire_terrier/American_staffordshire_terrier_00578.jpg
# Img: /data/dog_images/train/019.Bedlington_terrier/Bedlington_terrier_01394.jpg
# Img: /data/dog_images/train/072.German_shorthaired_pointer/German_shorthaired_pointer_05001.jpg
# Img: /data/dog_images/train/016.Beagle/Beagle_01195.jpg
# Img: /data/dog_images/train/016.Beagle/Beagle_01160.jpg
# Img: /data/dog_images/train/006.American_eskimo_dog/American_eskimo_dog_00426.jpg
# Img: /data/dog_images/train/118.Pembroke_welsh_corgi/Pembroke_welsh_corgi_07646.jpg
# Img: /data/dog_images/train/076.Golden_retriever/Golden_retriever_05257.jpg
# Img: /data/dog_images/train/060.Dogue_de_bordeaux/Dogue_de_bordeaux_04241.jpg
# Img: /data/dog_images/train/104.Miniature_schnauzer/Miniature_schnauzer_06932.jpg
# Img: /data/dog_images/train/063.English_springer_spaniel/English_springer_spaniel_04448.jpg
# Img: /data/dog_images/train/010.Anatolian_shepherd_dog/Anatolian_shepherd_dog_00718.jpg
# Img: /data/dog_images/train/056.Dachshund/Dachshund_03968.jpg
# Img: /data/dog_images/train/017.Bearded_collie/Bearded_collie_01238.jpg
# Img: /data/dog_images/train/013.Australian_terrier/Australian_terrier_00902.jpg
# Img: /data/dog_images/train/021.Belgian_sheepdog/Belgian_sheepdog_01500.jpg
# Img: /data/dog_images/train/057.Dalmatian/Dalmatian_04017.jpg
# Img: /data/dog_images/train/019.Bedlington_terrier/Bedlington_terrier_01345.jpg
# Img: /data/dog_images/train/124.Poodle/Poodle_07941.jpg
# Img: /data/dog_images/train/038.Brussels_griffon/Brussels_griffon_02654.jpg
# Img: /data/dog_images/train/075.Glen_of_imaal_terrier/Glen_of_imaal_terrier_05154.jpg
# Img: /data/dog_images/train/070.German_pinscher/German_pinscher_04880.jpg
# Img: /data/dog_images/train/072.German_shorthaired_pointer/German_shorthaired_pointer_04973.jpg
# Img: /data/dog_images/train/125.Portuguese_water_dog/Portuguese_water_dog_07987.jpg
# Img: /data/dog_images/train/001.Affenpinscher/Affenpinscher_00060.jpg
# Img: /data/dog_images/train/115.Papillon/Papillon_07452.jpg
# Img: /data/dog_images/train/094.Komondor/Komondor_06337.jpg
# Img: /data/dog_images/train/027.Bloodhound/Bloodhound_01945.jpg
# Img: /data/dog_images/train/091.Japanese_chin/Japanese_chin_06219.jpg
# Img: /data/dog_images/train/078.Great_dane/Great_dane_05336.jpg
# Img: /data/dog_images/train/129.Tibetan_mastiff/Tibetan_mastiff_08131.jpg
# Img: /data/dog_images/train/117.Pekingese/Pekingese_07608.jpg
# Img: /data/dog_images/train/117.Pekingese/Pekingese_07600.jpg
# Img: /data/dog_images/train/054.Collie/Collie_03832.jpg
# Img: /data/dog_images/train/056.Dachshund/Dachshund_03965.jpg
# Img: /data/dog_images/train/107.Norfolk_terrier/Norfolk_terrier_07090.jpg
# Img: /data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03764.jpg
# Img: /data/dog_images/train/018.Beauceron/Beauceron_01291.jpg
# Img: /data/dog_images/train/033.Bouvier_des_flandres/Bouvier_des_flandres_02321.jpg
# Img: /data/dog_images/train/101.Maltese/Maltese_06729.jpg
# Img: /data/dog_images/train/098.Leonberger/Leonberger_06598.jpg
# Img: /data/dog_images/train/010.Anatolian_shepherd_dog/Anatolian_shepherd_dog_00686.jpg
# Img: /data/dog_images/train/014.Basenji/Basenji_00999.jpg
# Img: /data/dog_images/train/027.Bloodhound/Bloodhound_01879.jpg
# Img: /data/dog_images/train/028.Bluetick_coonhound/Bluetick_coonhound_01969.jpg
# Img: /data/dog_images/train/044.Cane_corso/Cane_corso_03101.jpg
# Img: /data/dog_images/train/015.Basset_hound/Basset_hound_01089.jpg
# Img: /data/dog_images/train/079.Great_pyrenees/Great_pyrenees_05416.jpg
# Img: /data/dog_images/train/047.Chesapeake_bay_retriever/Chesapeake_bay_retriever_03345.jpg
# Img: /data/dog_images/train/043.Canaan_dog/Canaan_dog_03089.jpg
# Img: /data/dog_images/train/006.American_eskimo_dog/American_eskimo_dog_00413.jpg
# Img: /data/dog_images/train/041.Bullmastiff/Bullmastiff_02939.jpg
# Img: /data/dog_images/train/112.Nova_scotia_duck_tolling_retriever/Nova_scotia_duck_tolling_retriever_07329.jpg
# Img: /data/dog_images/train/074.Giant_schnauzer/Giant_schnauzer_05082.jpg
# Img: /data/dog_images/train/097.Lakeland_terrier/Lakeland_terrier_06537.jpg
# Img: /data/dog_images/train/091.Japanese_chin/Japanese_chin_06195.jpg
# Img: /data/dog_images/train/043.Canaan_dog/Canaan_dog_03056.jpg
# Img: /data/dog_images/train/122.Pointer/Pointer_07814.jpg
# Img: /data/dog_images/train/030.Border_terrier/Border_terrier_02143.jpg
# Img: /data/dog_images/train/118.Pembroke_welsh_corgi/Pembroke_welsh_corgi_07660.jpg
# Img: /data/dog_images/train/113.Old_english_sheepdog/Old_english_sheepdog_07388.jpg
# Img: /data/dog_images/train/070.German_pinscher/German_pinscher_04874.jpg
# Img: /data/dog_images/train/114.Otterhound/Otterhound_07429.jpg
# Img: /data/dog_images/train/093.Kerry_blue_terrier/Kerry_blue_terrier_06304.jpg
# Img: /data/dog_images/train/013.Australian_terrier/Australian_terrier_00889.jpg
# Img: /data/dog_images/train/074.Giant_schnauzer/Giant_schnauzer_05097.jpg
# Img: /data/dog_images/train/019.Bedlington_terrier/Bedlington_terrier_01380.jpg
# Img: /data/dog_images/train/128.Smooth_fox_terrier/Smooth_fox_terrier_08111.jpg
# Img: /data/dog_images/train/076.Golden_retriever/Golden_retriever_05185.jpg
# Img: /data/dog_images/train/015.Basset_hound/Basset_hound_01113.jpg
# Img: /data/dog_images/train/048.Chihuahua/Chihuahua_03436.jpg
# Img: /data/dog_images/train/006.American_eskimo_dog/American_eskimo_dog_00443.jpg

# %% [markdown]
# ---
# <a id='step2'></a>
#
# ## 步骤 2: 检测狗狗
#
# 在这个部分中，我们使用预训练的 [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) 模型去检测图像中的狗。下方的第一行代码就是下载了 ResNet-50 模型的网络结构参数，以及基于 [ImageNet](http://www.image-net.org/) 数据集的预训练权重。
#
# ImageNet 这目前一个非常流行的数据集，常被用来测试图像分类等计算机视觉任务相关的算法。它包含超过一千万个 URL，每一个都链接到 [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a) 中所对应的一个物体的图像。任给输入一个图像，该 ResNet-50 模型会返回一个对图像中物体的预测结果。

# %%
from keras.applications.resnet50 import ResNet50

# 定义ResNet50模型
ResNet50_model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102858752/102853048 [==============================] - 3s 0us/step

# %% [markdown]
# ### 数据预处理
#
# - 在使用 TensorFlow 作为后端的时候，在 Keras 中，CNN 的输入是一个4维数组（也被称作4维张量），它的各维度尺寸为 `(nb_samples, rows, columns, channels)`。其中 `nb_samples` 表示图像（或者样本）的总数，`rows`, `columns`, 和 `channels` 分别表示图像的行数、列数和通道数。
#
#
# - 下方的 `path_to_tensor` 函数实现如下将彩色图像的字符串型的文件路径作为输入，返回一个4维张量，作为 Keras CNN 输入。因为我们的输入图像是彩色图像，因此它们具有三个通道（ `channels` 为 `3`）。
#     1. 该函数首先读取一张图像，然后将其缩放为 224×224 的图像。
#     2. 随后，该图像被调整为具有4个维度的张量。
#     3. 对于任一输入图像，最后返回的张量的维度是：`(1, 224, 224, 3)`。
#
#
# - `paths_to_tensor` 函数将图像路径的字符串组成的 numpy 数组作为输入，并返回一个4维张量，各维度尺寸为 `(nb_samples, 224, 224, 3)`。 在这里，`nb_samples`是提供的图像路径的数据中的样本数量或图像数量。你也可以将 `nb_samples` 理解为数据集中3维张量的个数（每个3维张量表示一个不同的图像。

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # 用PIL加载RGB图像为PIL.Image.Image类型
    img = image.load_img(img_path, target_size=(224, 224))
    # 将PIL.Image.Image类型转化为格式为(224, 224, 3)的3维张量
    x = image.img_to_array(img)
    # 将3维张量转化为格式为(1, 224, 224, 3)的4维张量并返回
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### 基于 ResNet-50 架构进行预测
#
# 对于通过上述步骤得到的四维张量，在把它们输入到 ResNet-50 网络、或 Keras 中其他类似的预训练模型之前，还需要进行一些额外的处理：
# 1. 首先，这些图像的通道顺序为 RGB，我们需要重排他们的通道顺序为 BGR。
# 2. 其次，预训练模型的输入都进行了额外的归一化过程。因此我们在这里也要对这些张量进行归一化，即对所有图像所有像素都减去像素均值 `[103.939, 116.779, 123.68]`（以 RGB 模式表示，根据所有的 ImageNet 图像算出）。
#
# 导入的 `preprocess_input` 函数实现了这些功能。如果你对此很感兴趣，可以在 [这里](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py) 查看 `preprocess_input`的代码。
#
#
# 在实现了图像处理的部分之后，我们就可以使用模型来进行预测。这一步通过 `predict` 方法来实现，它返回一个向量，向量的第 i 个元素表示该图像属于第 i 个 ImageNet 类别的概率。这通过如下的 `ResNet50_predict_labels` 函数实现。
#
# 通过对预测出的向量取用 argmax 函数（找到有最大概率值的下标序号），我们可以得到一个整数，即模型预测到的物体的类别。进而根据这个 [清单](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a)，我们能够知道这具体是哪个品种的狗狗。

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions
def ResNet50_predict_labels(img_path):
    # 返回img_path路径的图像的预测向量
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### 完成狗检测模型
#
#
# 在研究该 [清单](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a) 的时候，你会注意到，狗类别对应的序号为151-268。因此，在检查预训练模型判断图像是否包含狗的时候，我们只需要检查如上的 `ResNet50_predict_labels` 函数是否返回一个介于151和268之间（包含区间端点）的值。
#
# 我们通过这些想法来完成下方的 `dog_detector` 函数，如果从图像中检测到狗就返回 `True`，否则返回 `False`。

# %%
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### 【作业】评估狗狗检测模型
#
# ---
#
# <a id='question3'></a>
# ### __问题 3:__
#
# 在下方的代码块中，使用 `dog_detector` 函数，计算：
#
# - `human_files_short`中图像检测到狗狗的百分比？
# - `dog_files_short`中图像检测到狗狗的百分比？

# %%
### TODO: 测试dog_detector函数在human_files_short和dog_files_short的表现
dogInHumans = np.sum([dog_detector(img) for img in human_files_short])
dogInDogs = np.sum([dog_detector(img) for img in dog_files_short])
print("%d of the images in human_files_short have a detected dog." % dogInHumans)
print("%d of the images in dog_files_short have a detected dog." % dogInDogs)
# Out:
# 0 of the images in human_files_short have a detected dog.
# 100 of the images in dog_files_short have a detected dog.

# %% [markdown]
# __回答__:
# - human_files_short中图像检测到狗狗的百分比:0%
# - dog_files_short中图像检测到狗狗的百分比:100%

# %% [markdown]
# ---
#
# <a id='step3'></a>
#
# ## 步骤 3: 从头开始创建一个CNN来分类狗品种
#
#
# 现在我们已经实现了一个函数，能够在图像中识别人类及狗狗。但我们需要更进一步的方法，来对狗的类别进行识别。在这一步中，你需要实现一个卷积神经网络来对狗的品种进行分类。你需要__从头实现__你的卷积神经网络（在这一阶段，你还不能使用迁移学习），并且你需要达到超过1%的测试集准确率。在本项目的步骤五种，你还有机会使用迁移学习来实现一个准确率大大提高的模型。
#
# 在添加卷积层的时候，注意不要加上太多的（可训练的）层。更多的参数意味着更长的训练时间，也就是说你更可能需要一个 GPU 来加速训练过程。万幸的是，Keras 提供了能够轻松预测每次迭代（epoch）花费时间所需的函数。你可以据此推断你算法所需的训练时间。
#
# 值得注意的是，对狗的图像进行分类是一项极具挑战性的任务。因为即便是一个正常人，也很难区分布列塔尼犬和威尔士史宾格犬。
#
#
# 布列塔尼犬（Brittany） | 威尔士史宾格犬（Welsh Springer Spaniel）
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# 不难发现其他的狗品种会有很小的类间差别（比如金毛寻回犬和美国水猎犬）。
#
#
# 金毛寻回犬（Curly-Coated Retriever） | 美国水猎犬（American Water Spaniel）
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
# 同样，拉布拉多犬（labradors）有黄色、棕色和黑色这三种。那么你设计的基于视觉的算法将不得不克服这种较高的类间差别，以达到能够将这些不同颜色的同类狗分到同一个品种中。
#
# 黄色拉布拉多犬（Yellow Labrador） | 棕色拉布拉多犬（Chocolate Labrador） | 黑色拉布拉多犬（Black Labrador）
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# 我们也提到了随机分类将得到一个非常低的结果：不考虑品种略有失衡的影响，随机猜测到正确品种的概率是1/133，相对应的准确率是低于1%的。
#
# 请记住，在深度学习领域，实践远远高于理论。大量尝试不同的框架吧，相信你的直觉！当然，玩得开心！
#
#
# ### 数据预处理
#
#
# 通过对每张图像的像素值除以255，我们对图像实现了归一化处理。

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# Keras中的数据预处理过程
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [01:14<00:00, 89.34it/s]
# 100%|██████████| 835/835 [00:08<00:00, 100.25it/s]
# 100%|██████████| 836/836 [00:08<00:00, 99.64it/s]

# %% [markdown]
# ### 【练习】模型架构
#
#
# 创建一个卷积神经网络来对狗品种进行分类。在你代码块的最后，执行 `model.summary()` 来输出你模型的总结信息。
#
# 我们已经帮你导入了一些所需的 Python 库，如有需要你可以自行导入。如果你在过程中遇到了困难，如下是给你的一点小提示——该模型能够在5个 epoch 内取得超过1%的测试准确率，并且能在CPU上很快地训练。
#
# ![Sample CNN](images/sample_cnn.png)

# %% [markdown]
# ---
#
# <a id='question4'></a>
#
# ### __问题 4:__
#
# 在下方的代码块中尝试使用 Keras 搭建卷积网络的架构，并回答相关的问题。
#
# 1. 你可以尝试自己搭建一个卷积网络的模型，那么你需要回答你搭建卷积网络的具体步骤（用了哪些层）以及为什么这样搭建。
# 2. 你也可以根据上图提示的步骤搭建卷积网络，那么请说明为何如上的架构能够在该问题上取得很好的表现。
#
# __回答:__
# 我认为增加过滤器的数量可以使模型更有效地训练。一开始，它可能只能适配高层次的特征。但是，随着时间的推移，它可以更好地将这些特征连接在一起，可以获得更完整的图像。在每次Conv之后，模型通过MaxPooling来减少参数的数量，从而在网络中进行计算。然后，第三层pooling层将会扁平化至一个维度并且穿过两个connected layer.因此，ReLU将再次用于除输出密集层之外的所有层，输出密集层将被softmax激活进行分类。详情见下方结果。

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(9,9), input_shape=(224, 224, 3)))

model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding='same'))
model.add(Conv2D(filters=64, kernel_size=(7,7)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1,1), padding='same'))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.1))
model.add(Dense(500))
model.add(Activation("relu"))
model.add(Dense(133))
model.add(Activation("softmax"))
model.summary()


### TODO: 定义你的网络架构
                 
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 216, 216, 32)      7808
# _________________________________________________________________
# activation_50 (Activation)   (None, 216, 216, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 102, 102, 64)      100416
# _________________________________________________________________
# activation_51 (Activation)   (None, 102, 102, 64)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 102, 102, 64)      0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               32500
# _________________________________________________________________
# activation_52 (Activation)   (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               66633
# _________________________________________________________________
# activation_53 (Activation)   (None, 133)               0
# =================================================================
# Total params: 207,357
# Trainable params: 207,357
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 216, 216, 32)      7808
# _________________________________________________________________
# activation_50 (Activation)   (None, 216, 216, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 102, 102, 64)      100416
# _________________________________________________________________
# activation_51 (Activation)   (None, 102, 102, 64)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 102, 102, 64)      0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               32500
# _________________________________________________________________
# activation_52 (Activation)   (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               66633
# _________________________________________________________________
# activation_53 (Activation)   (None, 133)               0
# =================================================================
# Total params: 207,357
# Trainable params: 207,357
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 编译模型
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ---

# %% [markdown]
# ## 【练习】训练模型
#
#
# ---
#
# <a id='question5'></a>
#
# ### __问题 5:__
#
# 在下方代码单元训练模型。使用模型检查点（model checkpointing）来储存具有最低验证集 loss 的模型。
#
# 可选题：你也可以对训练集进行 [数据增强](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)，来优化模型的表现。

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: 设置训练模型的epochs的数量

epochs = 5

### 不要修改下方代码

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.8870 - acc: 0.0092Epoch 00001: val_loss improved from inf to 4.86794, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 41s 6ms/step - loss: 4.8871 - acc: 0.0091 - val_loss: 4.8679 - val_acc: 0.0108
# Epoch 2/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.8377 - acc: 0.0158Epoch 00002: val_loss improved from 4.86794 to 4.81418, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 40s 6ms/step - loss: 4.8375 - acc: 0.0157 - val_loss: 4.8142 - val_acc: 0.0156
# Epoch 3/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.7753 - acc: 0.0165Epoch 00003: val_loss improved from 4.81418 to 4.74757, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 40s 6ms/step - loss: 4.7751 - acc: 0.0166 - val_loss: 4.7476 - val_acc: 0.0204
# Epoch 4/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.7110 - acc: 0.0212Epoch 00004: val_loss improved from 4.74757 to 4.70311, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 40s 6ms/step - loss: 4.7105 - acc: 0.0213 - val_loss: 4.7031 - val_acc: 0.0263
# Epoch 5/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.6599 - acc: 0.0272Epoch 00005: val_loss improved from 4.70311 to 4.69404, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 40s 6ms/step - loss: 4.6601 - acc: 0.0271 - val_loss: 4.6940 - val_acc: 0.0216

# %%
print(train_tensors.shape)
# Out:
# (6680, 224, 224, 3)

# %%
## 加载具有最好验证loss的模型

model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### 测试模型
#
# 在狗图像的测试数据集上试用你的模型。确保测试准确率大于1%。

# %%
# 获取测试数据集中每一个图像所预测的狗品种的index
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# 报告测试准确率
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 2.9904%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## 步骤 4: 使用一个CNN来区分狗的品种
#
#
# 使用 迁移学习（Transfer Learning）的方法，能帮助我们在不损失准确率的情况下大大减少训练时间。在以下步骤中，你可以尝试使用迁移学习来训练你自己的CNN。

# %% [markdown]
# ### 得到从图像中提取的特征向量（Bottleneck Features）

# %%
bottleneck_features = np.load('/data/bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

print(train_VGG16.shape)
print(valid_VGG16.shape)
print(test_VGG16.shape)
# Out:
# (6680, 7, 7, 512)
# (835, 7, 7, 512)
# (836, 7, 7, 512)

# %% [markdown]
# ### 模型架构
#
# 该模型使用预训练的 VGG-16 模型作为固定的图像特征提取器，其中 VGG-16 最后一层卷积层的输出被直接输入到我们的模型。我们只需要添加一个全局平均池化层以及一个全连接层，其中全连接层使用 softmax 激活函数，对每一个狗的种类都包含一个节点。

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 编译模型

VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
## 训练模型

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 12.4669 - acc: 0.1233Epoch 00001: val_loss improved from inf to 11.22302, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 303us/step - loss: 12.4679 - acc: 0.1231 - val_loss: 11.2230 - val_acc: 0.1988
# Epoch 2/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 10.7308 - acc: 0.2529Epoch 00002: val_loss improved from 11.22302 to 10.63166, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 258us/step - loss: 10.7305 - acc: 0.2531 - val_loss: 10.6317 - val_acc: 0.2587
# Epoch 3/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 10.1895 - acc: 0.3089Epoch 00003: val_loss improved from 10.63166 to 10.31860, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss:
20
# 6480/6680 [============================>.] - ETA: 0s - loss: 7.6281 - acc: 0.5196Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 7.6415 - acc: 0.5187 - val_loss: 8.4849 - val_acc: 0.3988

# %%
## 加载具有最好验证loss的模型

VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### 测试模型
# 现在，我们可以测试此CNN在狗图像测试数据集中识别品种的效果如何。我们在下方打印出测试准确率。

# %%
# 获取测试数据集中每一个图像所预测的狗品种的index
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# 报告测试准确率
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 39.5933%

# %% [markdown]
# ### 使用模型预测狗的品种

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # 提取bottleneck特征
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # 获取预测向量
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # 返回此模型预测的狗的品种
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## 步骤 5: 建立一个CNN来分类狗的品种（使用迁移学习）
#
# 现在你将使用迁移学习来建立一个CNN，从而可以从图像中识别狗的品种。你的 CNN 在测试集上的准确率必须至少达到60%。
#
# 在步骤4中，我们使用了迁移学习来创建一个使用基于 VGG-16 提取的特征向量来搭建一个 CNN。在本部分内容中，你必须使用另一个预训练模型来搭建一个 CNN。为了让这个任务更易实现，我们已经预先对目前 keras 中可用的几种网络进行了预训练：
#
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# 这些文件被命名为为：
#
#     Dog{network}Data.npz
#
# 其中 `{network}` 可以是 `VGG19`、`Resnet50`、`InceptionV3` 或 `Xception` 中的一个。选择上方网络架构中的一个，他们已经保存在目录 `/data/bottleneck_features/` 中。
#
#
# ### 【练习】获取模型的特征向量
#
# 在下方代码块中，通过运行下方代码提取训练、测试与验证集相对应的bottleneck特征。
#
#     bottleneck_features = np.load('/data/bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: 从另一个预训练的CNN获取bottleneck特征
bottleneck_features = np.load('/data/bottleneck_features/DogInceptionV3Data.npz')
train_Inception = bottleneck_features['train']
valid_Inception = bottleneck_features['valid']
test_Inception = bottleneck_features['test']

print(train_Inception.shape)
print(valid_Inception.shape)
print(test_Inception.shape)
# Out:
# (6680, 5, 5, 2048)
# (835, 5, 5, 2048)
# (836, 5, 5, 2048)

# %% [markdown]
# ### 【练习】模型架构
#
# 建立一个CNN来分类狗品种。在你的代码单元块的最后，通过运行如下代码输出网络的结构：
#
#         <your model's name>.summary()
#
# ---
#
# <a id='question6'></a>
#
# ### __问题 6:__
#
#
# 在下方的代码块中尝试使用 Keras 搭建最终的网络架构，并回答你实现最终 CNN 架构的步骤与每一步的作用，并描述你在迁移学习过程中，使用该网络架构的原因。
#
#
# __回答:__
# 原来的CurePosiv3应用了很多的CONV和POOL过滤器，所以我觉得没必要将卷积加入到我的网络中了。倘若我需要进一步卷积应用于我的网络中。当我加了很多CONV-POOL层的时候，训练速度变慢了，但是我却没发现模型的loss和accuracy获得了多少提升。我觉得我肯定做的哪里有问题，所以就中断了训练并且改进了模型。我的新想法是，压缩通过初始权重处理的最佳特征，并将其并入非线性神经网络。我认为添加一个适合的GAP层很有必要，理由如下：
# - 1.它从通过起始权值处理的图像中检索出最佳特征；
# - 2.它可以把数据扁平化，并且扁平化可以带来bonus。
#
# 另外，我选择在relu和sigmoid的上选择了tanh算是经验之谈。
# 我觉得一般来说，在这种情况下，tanh比其他激活功能更好。选取0.2作为参数的值而不是0.1也同样是经验之谈。通过试验我的参数选取确实是正确的。

# %%
### TODO: 定义你的框架
Inc_model = Sequential()
Inc_model.add(GlobalAveragePooling2D(input_shape=train_Inception.shape[1:]))
Inc_model.add(Dense(500))
Inc_model.add(Activation("tanh"))
Inc_model.add(Dropout(0.2))
Inc_model.add(Dense(133, activation='softmax'))
Inc_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# activation_54 (Activation)   (None, 500)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 1,091,133
# Trainable params: 1,091,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
### TODO: 编译模型
Inc_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ---
#
# ### 【练习】训练模型
#
# <a id='question7'></a>
#
# ### __问题 7:__
#
# 在下方代码单元中训练你的模型。使用模型检查点（model checkpointing）来储存具有最低验证集 loss 的模型。
#
# 当然，你也可以对训练集进行 [数据增强](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html) 以优化模型的表现，不过这不是必须的步骤。

# %%
### TODO: 训练模型
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Inc_model.hdf5', 
                               verbose=1, save_best_only=True)

Inc_model.fit(train_Inception, train_targets, 
          validation_data=(valid_Inception, valid_targets),
          epochs=200, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.4027 - acc: 0.8769Epoch 00001: val_loss improved from inf to 0.59837, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 3s 459us/step - loss: 0.4018 - acc: 0.8772 - val_loss: 0.5984 - val_acc: 0.8240
# Epoch 2/200
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.3284 - acc: 0.8959Epoch 00002: val_loss did not improve
# 6680/6680 [==============================] - 3s 451us/step - loss: 0.3299 - acc: 0.8951 - val_loss: 0.6076 - val_acc: 0.8275
# Epoch 3/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.2820 - acc: 0.9083Epoch 00003: val_loss improved from 0.59837 to 0.57035, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 3s 455us/step - loss: 0.2821 - acc: 0.9082 - val_loss: 0.5704 - val_acc: 0.8347
# Epoch 4/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.2322 - acc: 0.9270Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 3s 453us/step - loss: 0.2322 - acc: 0.9271 - val_loss: 0.5878 - val_acc: 0.8359
# Epoch 5/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.1994 - acc: 0.9353Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 3s 448us/step - loss: 0.2031 - acc: 0.9346 - val_loss: 0.6524 - val_acc: 0.8359
# Epoch 6/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.1660 - acc: 0.9464Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 3s 451us/step - loss: 0.1664 - acc: 0.9466 - val_loss: 0.6052 - val_acc: 0.8335
# Epoch 7/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.1502 - acc: 0.9520Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 3s 450us/step - loss: 0.1503 - acc: 0.9516 - val_loss: 0.5927 - val_acc: 0.8431
# Epoch 8/200
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.1260 - acc: 0.9634Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 3s 451us/step - loss: 0.1258 - acc: 0.9635 - val_loss: 0.6472 - val_acc: 0.8383
# Epoch 9/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1129 - acc: 0.9661Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 3s 449us/step - loss: 0.1127 - acc: 0.9662 - val_loss: 0.6232 - val_acc: 0.8395
# Epoch 10/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0973 - acc: 0.9703Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 3s 452us/step - loss: 0.0968 - acc: 0.9705 - val_loss: 0.6329 - val_acc: 0.8515
# Epoch 11/200
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0859 - acc: 0.9749Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 3s 453us/step - loss: 0.0861 - acc: 0.9747 - val_loss: 0.6842 - val_acc: 0.8443
# Epoch 12/200
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0798 - acc: 0.9787Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 3s 456us/step - loss: 0.0798 - acc: 0.9787 - val_loss: 0.6704 - val_acc: 0.8527
# Epoch 13/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0634 - acc: 0.9800Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 3s 452us/step - loss: 0.0632 - acc: 0.9801 - val_loss: 0.6703 - val_acc: 0.8407
# Epoch 14/200
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0623 - acc: 0.9822Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 3s 451us/step - loss: 0.0626 - acc: 0.9819 - val_loss: 0.6737 - val_acc: 0.8443
# Epoch 15/200
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0566 - acc: 0.9846Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 3s 451us/step - loss: 0.0570 - acc: 0.9844 - val_loss: 0.6935 - val_acc: 0.8371
# Epoch 16/200
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0514 - acc: 0.9829Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 3s 453us/step - loss: 0.0510 - acc: 0.9829 - val_loss: 0.7045 - val_acc: 0.8407
# Epoch 17/200
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0468 - acc: 0.9878Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 3s 451us/step - loss: 0.
#
# 在狗图像的测试数据集上试用你的模型。确保测试准确率大于60%。

# %%
### TODO: 在测试集上计算分类准确率
Inc_predictions = [np.argmax(Inc_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Inception]
test_accuracy = 100*np.sum(np.array(Inc_predictions)==np.argmax(test_targets, axis=1))/len(Inc_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 79.9043%

# %% [markdown]
# ---
#
# ### 【练习】使用模型测试狗的品种
#
#
# 实现一个函数，它的输入为图像路径，功能为预测对应图像的类别，输出为你模型预测出的狗类别（`Affenpinscher`, `Afghan_hound` 等）。
#
# 与步骤5中的模拟函数类似，你的函数应当包含如下三个步骤：
#
# 1. 根据选定的模型载入图像特征（bottleneck features）
# 2. 将图像特征输输入到你的模型中，并返回预测向量。注意，在该向量上使用 argmax 函数可以返回狗种类的序号。
# 3. 使用在步骤0中定义的 `dog_names` 数组来返回对应的狗种类名称。
#
# 提取图像特征过程中使用到的函数可以在 `extract_bottleneck_features.py` 中找到。同时，他们应已在之前的代码块中被导入。根据你选定的 CNN 网络，你可以使用 `extract_{network}` 函数来获得对应的图像特征，其中 `{network}` 代表 `VGG19`, `Resnet50`, `InceptionV3`, 或 `Xception` 中的一个。
#
# ---
#
# <a id='question9'></a>
#
# ### __问题 9:__

# %%
### TODO: 写一个函数，该函数将图像的路径作为输入
### 然后返回此模型所预测的狗的品种
def Inc_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_InceptionV3(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = Inc_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
#
# <a id='step6'></a>
# ## 步骤 6: 完成你的算法
#
#
#
# 实现一个算法，它的输入为图像的路径，它能够区分图像是否包含一个人、狗或两者都不包含，然后：
#
# - 如果从图像中检测到一只__狗__，返回被预测的品种。
# - 如果从图像中检测到__人__，返回最相像的狗品种。
# - 如果两者都不能在图像中检测到，输出错误提示。
#
# 我们非常欢迎你来自己编写检测图像中人类与狗的函数，你可以随意地使用上方完成的 `face_detector` 和 `dog_detector` 函数。你__需要__在步骤5使用你的CNN来预测狗品种。
#
# 下面提供了算法的示例输出，但你可以自由地设计自己的模型！
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
#
#
# <a id='question10'></a>
#
# ### __问题 10:__
#
# 在下方代码块中完成你的代码。
#
# ---

# %%
### TODO: 设计你的算法
### 自由地使用所需的代码单元数吧

class NeitherDogNorHumanError(Exception):
    """Subclassing Error for clarity"""
    pass

def predict_breed_or_resemblance(img_path):
    creature = None
    message = None
    breed = None
    if dog_detector(img_path):
        creature = "dog"
        message = "your predicted breed is"
    
    if face_detector(img_path):
        creature = "human"
        message = "you look like a"
    
    if not creature:
        raise NeitherDogNorHumanError("Tis neither a dog nor a human!!!")
    
    breed = Inc_predict_breed(img_path)
    return "Hello, {}! {} ... {}".format(creature, message, breed)

# %% [markdown]
# ---
# <a id='step7'></a>
# ## 步骤 7: 测试你的算法
#
# 在这个部分中，你将尝试一下你的新算法！算法认为__你__看起来像什么类型的狗？如果你有一只狗，它可以准确地预测你的狗的品种吗？如果你有一只猫，它会将你的猫误判为一只狗吗？
#
#
# <a id='question11'></a>
#
# ### __问题 11:__
#
# 在下方编写代码，用至少6张现实中的图片来测试你的算法。你可以使用任意照片，不过请至少使用两张人类图片（要征得当事人同意哦）和两张狗的图片。
# 同时请回答如下问题：
#
# 1. 输出结果比你预想的要好吗 :) ？或者更糟 :( ？
# 2. 提出至少三点改进你的模型的想法。
#
# __回答__：
# 1. 输出的结果比我想象的要好，我尝试了6张图，结果正确率100%。
# 2. 改进想法如下：
# - 在预测分类概率时，改为基于最大的分类概率而不是short-circuiting
# - 另一种改进可能的改进是建立多个模型并进行集成学习。
# - 还有一种改进可能就是多尝试改变各种参数以及确定最小的阈值以改进学习结果。
#
# __批改老师的建议__：
# - 交叉验证（Cross Validation）
# 在本次训练中，我们只进行了一次训练集/测试集切分，而在实际模型训练过程中，我们往往是使用交叉验证（Cross Validation）来进行模型选择（Model Selection）和调参（Parameter Tunning）的。交叉验证的通常做法是，按照某种方式多次进行训练集/测试集切分，最终取平均值（加权平均值），具体可以参考维基百科的介绍。
# - 模型融合/集成学习（Model Ensembling）
# 通过利用一些机器学习中模型融合的技术，如voting、bagging、blending以及staking等，可以显著提高模型的准确率与鲁棒性，且几乎没有风险。你可以参考我整理的机器学习笔记中的Ensemble部分。
# - 更多的数据
# 对于深度学习（机器学习）任务来说，更多的数据意味着更为丰富的输入空间，可以带来更好的训练效果。我们可以通过数据增强（Data Augmentation）、对抗生成网络（Generative Adversarial Networks）等方式来对数据集进行扩充，同时这种方式也能提升模型的鲁棒性。
# - 更换人脸检测算法
# 尽管OpenCV工具包非常方便并且高效，Haar级联检测也是一个可以直接使用的强力算法，但是这些算法仍然不能获得很高的准确率，并且需要用户提供正面照片，这带来的一定的不便。所以如果想要获得更好的用户体验和准确率，我们可以尝试一些新的人脸识别算法，如基于深度学习的一些算法。
# - 多目标监测
# 更进一步，我们可以通过一些先进的目标识别算法，如RCNN、Fast-RCNN、Faster-RCNN或Masked-RCNN等，来完成一张照片中同时出现多个目标的检测任务。

# %%
## TODO: 在你的电脑上，在步骤6中，至少在6张图片上运行你的算法。
## 自由地使用所需的代码单元数吧

print(predict_breed_or_resemblance("/data/dog_images/test/001.Affenpinscher/Affenpinscher_00003.jpg"))
print(predict_breed_or_resemblance("/data/dog_images/test/115.Papillon/Papillon_07480.jpg"))
print(predict_breed_or_resemblance("/data/dog_images/test/019.Bedlington_terrier/Bedlington_terrier_01363.jpg"))
print(predict_breed_or_resemblance("/data/dog_images/test/068.Flat-coated_retriever/Flat-coated_retriever_04703.jpg"))
print(predict_breed_or_resemblance("/data/lfw/Lucia_Kenny_Anthony/Lucia_Kenny_Anthony_0001.jpg"))
print(predict_breed_or_resemblance("/data/lfw/Richard_Myers/Richard_Myers_0002.jpg"))
# Out:
# Hello, dog! your predicted breed is ... in/001.Affenpinscher
# Hello, human! you look like a ... in/115.Papillon
# Hello, dog! your predicted breed is ... in/019.Bedlington_terrier
# Hello, dog! your predicted breed is ... in/068.Flat-coated_retriever
# Hello, human! you look like a ... in/011.Australian_cattle_dog
# Hello, human! you look like a ... in/088.Irish_water_spaniel

# %% [markdown]
# **注意: 当你写完了所有的代码，并且回答了所有的问题。你就可以把你的 iPython Notebook 导出成 HTML 文件。你可以在菜单栏，这样导出File -> Download as -> HTML (.html)把这个 HTML 和这个 iPython notebook 一起做为你的作业提交。**
